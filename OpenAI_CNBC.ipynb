# %%
pip install openai chromadb beautifulsoup4 requests sentence-transformers lxml
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Collecting openai
#   Downloading openai-2.8.1-py3-none-any.whl.metadata (29 kB)
# Collecting chromadb
#   Downloading chromadb-1.3.5-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (4.12.3)
# Requirement already satisfied: requests in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (2.32.2)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.1.2-py3-none-any.whl.metadata (16 kB)
# Collecting lxml
#   Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai) (4.4.0)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai) (0.27.0)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.12.4-py3-none-any.whl.metadata (89 kB)
#      ---------------------------------------- 0.0/89.9 kB ? eta -:--:--
#      ------------------ --------------------- 41.0/89.9 kB ? eta -:--:--
#      ------------------------------------ --- 81.9/89.9 kB 1.5 MB/s eta 0:00:01
#      ------------------------------------ --- 81.9/89.9 kB 1.5 MB/s eta 0:00:01
#      ------------------------------------ --- 81.9/89.9 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 89.9/89.9 kB 363.6 kB/s eta 0:00:00
# Requirement already satisfied: sniffio in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai) (1.3.1)
# Collecting tqdm>4 (from openai)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai) (4.12.0)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.38.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from chromadb) (2.2.1)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Using cached posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.2-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting tokenizers>=0.13.2 (from chromadb)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached pypika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: overrides>=7.3.1 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from chromadb) (7.7.0)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting grpcio>=1.58.0 (from chromadb)
#   Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Using cached kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting tenacity>=8.2.3 (from chromadb)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from chromadb) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting orjson>=3.9.12 (from chromadb)
#   Downloading orjson-3.11.4-cp310-cp310-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      -------------------------------------- - 41.0/42.9 kB ? eta -:--:--
#      -------------------------------------- 42.9/42.9 kB 518.9 kB/s eta 0:00:00
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from chromadb) (4.22.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests) (2024.2.2)
# Collecting transformers<5.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/44.0 kB ? eta -:--:--
#      ------------------------------------- -- 41.0/44.0 kB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 41.0/44.0 kB 2.0 MB/s eta 0:00:01
#      ------------------------------------- -- 41.0/44.0 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 44.0/44.0 kB 180.5 kB/s eta 0:00:00
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.9.1-cp310-cp310-win_amd64.whl.metadata (30 kB)
# Requirement already satisfied: scikit-learn in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sentence-transformers) (1.6.0)
# Requirement already satisfied: scipy in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sentence-transformers) (1.14.1)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.1.5-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: Pillow in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: packaging>=19.1 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from build>=1.0.3->chromadb) (24.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from build>=1.0.3->chromadb) (2.0.1)
# Requirement already satisfied: httpcore==1.* in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Collecting filelock (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.2.0 (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# Collecting shellingham (from huggingface-hub>=0.20.0->sentence-transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting typer-slim (from huggingface-hub>=0.20.0->sentence-transformers)
#   Downloading typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=4.19.0->chromadb) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=4.19.0->chromadb) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=4.19.0->chromadb) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonschema>=4.19.0->chromadb) (0.18.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting google-auth>=1.0.1 (from kubernetes>=28.1.0->chromadb)
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Collecting protobuf (from onnxruntime>=1.14.1->chromadb)
#   Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting sympy (from onnxruntime>=1.14.1->chromadb)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting importlib-metadata<8.8.0,>=6.0 (from opentelemetry-api>=1.2.0->chromadb)
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting googleapis-common-protos~=1.57 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading googleapis_common_protos-1.72.0-py3-none-any.whl.metadata (9.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-extensions<5,>=4.11 (from openai)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Collecting huggingface-hub>=0.20.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Collecting regex!=2019.12.17 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2025.11.3-cp310-cp310-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.5 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.5 kB ? eta -:--:--
#      ---------------------------------------  41.0/41.5 kB ? eta -:--:--
#      -------------------------------------- 41.5/41.5 kB 181.9 kB/s eta 0:00:00
# Collecting safetensors>=0.4.3 (from transformers<5.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Collecting click>=8.0.0 (from typer>=0.9.0->chromadb)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting zipp>=3.20 (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb)
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime>=1.14.1->chromadb)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dzaki\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading openai-2.8.1-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    --------- ------------------------------ 0.2/1.0 MB 4.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.4/1.0 MB 5.5 MB/s eta 0:00:01
#    --------------------------- ------------ 0.7/1.0 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 1.0/1.0 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.8 MB/s eta 0:00:00
# Downloading chromadb-1.3.5-cp39-abi3-win_amd64.whl (21.7 MB)
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#     --------------------------------------- 0.3/21.7 MB 6.0 MB/s eta 0:00:04
#     --------------------------------------- 0.5/21.7 MB 5.5 MB/s eta 0:00:04
#    - -------------------------------------- 0.7/21.7 MB 5.8 MB/s eta 0:00:04
#    -- ------------------------------------- 1.1/21.7 MB 6.5 MB/s eta 0:00:04
#    -- ------------------------------------- 1.5/21.7 MB 6.7 MB/s eta 0:00:04
#    --- ------------------------------------ 1.9/21.7 MB 7.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.2/21.7 MB 7.2 MB/s eta 0:00:03
#    ---- ----------------------------------- 2.6/21.7 MB 6.8 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.9/21.7 MB 6.9 MB/s eta 0:00:03
#    ------ --------------------------------- 3.4/21.7 MB 7.2 MB/s eta 0:00:03
#    ------ --------------------------------- 3.7/21.7 MB 6.9 MB/s eta 0:00:03
#    ------- -------------------------------- 3.9/21.7 MB 7.1 MB/s eta 0:00:03
#    ------- -------------------------------- 4.2/21.7 MB 6.7 MB/s eta 0:00:03
#    -------- ------------------------------- 4.5/21.7 MB 6.6 MB/s eta 0:00:03
#    -------- ------------------------------- 4.9/21.7 MB 6.9 MB/s eta 0:00:03
#    --------- ------------------------------ 5.2/21.7 MB 6.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 5.6/21.7 MB 6.8 MB/s eta 0:00:03
#    ----------- ---------------------------- 6.0/21.7 MB 6.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 6.5/21.7 MB 7.1 MB/s eta 0:00:03
#    ------------ --------------------------- 7.0/21.7 MB 7.3 MB/s eta 0:00:02
#    ------------- -------------------------- 7.4/21.7 MB 7.4 MB/s eta 0:00:02
#    -------------- ------------------------- 7.7/21.7 MB 7.4 MB/s eta 0:00:02
#    --------------- ------------------------ 8.2/21.7 MB 7.6 MB/s eta 0:00:02
#    --------------- ------------------------ 8.4/21.7 MB 7.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 8.9/21.7 MB 7.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.2/21.7 MB 7.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.7/21.7 MB 7.6 MB/s eta 0:00:02
#    ------------------ --------------------- 10.0/21.7 MB 7.4 MB/s eta 0:00:02
#    ------------------- -------------------- 10.5/21.7 MB 7.5 MB/s eta 0:00:02
#    ------------------- -------------------- 10.8/21.7 MB 7.6 MB/s eta 0:00:02
#    -------------------- ------------------- 11.3/21.7 MB 7.8 MB/s eta 0:00:02
#    --------------------- ------------------ 11.7/21.7 MB 7.8 MB/s eta 0:00:02
#    ---------------------- ----------------- 12.1/21.7 MB 7.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 12.5/21.7 MB 8.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 13.0/21.7 MB 8.0 MB/s eta 0:00:02
#    ------------------------ --------------- 13.4/21.7 MB 8.1 MB/s eta 0:00:02
#    ------------------------- -------------- 13.9/21.7 MB 8.2 MB/s eta 0:00:01
#    ------------------------- -------------- 14.1/21.7 MB 8.1 MB/s eta 0:00:01
#    -------------------------- ------------- 14.6/21.7 MB 8.2 MB/s eta 0:00:01
#    --------------------------- ------------ 15.1/21.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 15.5/21.7 MB 8.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 15.8/21.7 MB 8.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 16.2/21.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------------ --------- 16.7/21.7 MB 8.5 MB/s eta 0:00:01
#    ------------------------------- -------- 17.1/21.7 MB 8.5 MB/s eta 0:00:01
#    -------------------------------- ------- 17.4/21.7 MB 8.3 MB/s eta 0:00:01
#    -------------------------------- ------- 17.8/21.7 MB 8.4 MB/s eta 0:00:01
#    --------------------------------- ------ 18.3/21.7 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 18.7/21.7 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 19.2/21.7 MB 8.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 19.5/21.7 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 19.9/21.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------- -- 20.3/21.7 MB 8.4 MB/s eta 0:00:01
#    ------------------------------------- -- 20.6/21.7 MB 8.4 MB/s eta 0:00:01
#    -------------------------------------- - 21.0/21.7 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  21.3/21.7 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  21.7/21.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 21.7/21.7 MB 7.2 MB/s eta 0:00:00
# Downloading sentence_transformers-5.1.2-py3-none-any.whl (488 kB)
#    ---------------------------------------- 0.0/488.0 kB ? eta -:--:--
#    -------------------------- ------------ 327.7/488.0 kB 10.2 MB/s eta 0:00:01
#    --------------------------------------  481.3/488.0 kB 10.0 MB/s eta 0:00:01
#    --------------------------------------  481.3/488.0 kB 10.0 MB/s eta 0:00:01
#    --------------------------------------  481.3/488.0 kB 10.0 MB/s eta 0:00:01
#    ---------------------------------------- 488.0/488.0 kB 2.4 MB/s eta 0:00:00
# Downloading lxml-6.0.2-cp310-cp310-win_amd64.whl (4.0 MB)
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.0 MB 9.8 MB/s eta 0:00:01
#    --------- ------------------------------ 0.9/4.0 MB 11.7 MB/s eta 0:00:01
#    -------------- ------------------------- 1.4/4.0 MB 11.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 1.8/4.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.3/4.0 MB 9.6 MB/s eta 0:00:01
#    -------------------------- ------------- 2.7/4.0 MB 9.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.3/4.0 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  4.0/4.0 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 7.0 MB/s eta 0:00:00
# Using cached bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Using cached build-1.3.0-py3-none-any.whl (23 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading grpcio-1.76.0-cp310-cp310-win_amd64.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    ----- ---------------------------------- 0.6/4.7 MB 18.2 MB/s eta 0:00:01
#    -------- ------------------------------- 1.0/4.7 MB 10.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.4/4.7 MB 10.9 MB/s eta 0:00:01
#    -------------- ------------------------- 1.7/4.7 MB 9.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.0/4.7 MB 9.9 MB/s eta 0:00:01
#    ------------------- -------------------- 2.3/4.7 MB 8.2 MB/s eta 0:00:01
#    ------------------------ --------------- 2.9/4.7 MB 8.7 MB/s eta 0:00:01
#    --------------------------- ------------ 3.2/4.7 MB 8.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.5/4.7 MB 8.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.8/4.7 MB 8.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 4.2/4.7 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------  4.7/4.7 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 6.0 MB/s eta 0:00:00
# Downloading jiter-0.12.0-cp310-cp310-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.8 kB ? eta -:--:--
#    --------------------------------------  204.8/204.8 kB 13.0 MB/s eta 0:00:01
#    --------------------------------------  204.8/204.8 kB 13.0 MB/s eta 0:00:01
#    ---------------------------------------- 204.8/204.8 kB 1.8 MB/s eta 0:00:00
# Using cached kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
# Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl (41 kB)
#    ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#    ---------------------------------------  41.0/41.5 kB ? eta -:--:--
#    ---------------------------------------- 41.5/41.5 kB 401.4 kB/s eta 0:00:00
# Downloading onnxruntime-1.23.2-cp310-cp310-win_amd64.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/13.5 MB 10.2 MB/s eta 0:00:02
#    - -------------------------------------- 0.7/13.5 MB 7.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/13.5 MB 8.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/13.5 MB 8.2 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.0/13.5 MB 8.5 MB/s eta 0:00:02
#    ------- -------------------------------- 2.5/13.5 MB 9.4 MB/s eta 0:00:02
#    -------- ------------------------------- 2.8/13.5 MB 8.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.3/13.5 MB 8.9 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.6/13.5 MB 8.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 4.0/13.5 MB 8.7 MB/s eta 0:00:02
#    ------------ --------------------------- 4.4/13.5 MB 8.4 MB/s eta 0:00:02
#    ------------- -------------------------- 4.7/13.5 MB 8.3 MB/s eta 0:00:02
#    -------------- ------------------------- 4.9/13.5 MB 8.4 MB/s eta 0:00:02
#    --------------- ------------------------ 5.1/13.5 MB 8.1 MB/s eta 0:00:02
#    --------------- ------------------------ 5.3/13.5 MB 7.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.5/13.5 MB 7.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 6.0/13.5 MB 7.9 MB/s eta 0:00:01
#    ------------------- -------------------- 6.5/13.5 MB 7.7 MB/s eta 0:00:01
#    ------------------- -------------------- 6.5/13.5 MB 7.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.8/13.5 MB 7.4 MB/s eta 0:00:01
#    -------------------- ------------------- 6.8/13.5 MB 7.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.9/13.5 MB 6.6 MB/s eta 0:00:01
#    -------------------- ------------------- 6.9/13.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.6/13.5 MB 6.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.8/13.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------ --------------- 8.2/13.5 MB 6.7 MB/s eta 0:00:01
#    ------------------------- -------------- 8.6/13.5 MB 6.7 MB/s eta 0:00:01
#    -------------------------- ------------- 9.0/13.5 MB 6.8 MB/s eta 0:00:01
#    --------------------------- ------------ 9.4/13.5 MB 6.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.9/13.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------ --------- 10.3/13.5 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 10.8/13.5 MB 7.1 MB/s eta 0:00:01
#    --------------------------------- ------ 11.2/13.5 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.7/13.5 MB 7.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.9/13.5 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 12.3/13.5 MB 6.9 MB/s eta 0:00:01
#    ------------------------------------- -- 12.7/13.5 MB 6.8 MB/s eta 0:00:01
#    -------------------------------------- - 13.1/13.5 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  13.3/13.5 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------  13.5/13.5 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 6.1 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#    ---------------------------------------- 0.0/65.9 kB ? eta -:--:--
#    ------------------------------------- -- 61.4/65.9 kB ? eta -:--:--
#    ------------------------------------- -- 61.4/65.9 kB ? eta -:--:--
#    ---------------------------------------- 65.9/65.9 kB 599.0 kB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#    ---------------------------------------- 0.0/72.5 kB ? eta -:--:--
#    ---------------------------------------  71.7/72.5 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  71.7/72.5 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 72.5/72.5 kB 566.3 kB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#    ---------------------------------------- 0.0/132.3 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/132.3 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/132.3 kB ? eta -:--:--
#    -------------------------------------- 132.3/132.3 kB 777.8 kB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#    ---------------------------------------- 0.0/208.0 kB ? eta -:--:--
#    --------------------------------------  204.8/208.0 kB 12.2 MB/s eta 0:00:01
#    --------------------------------------  204.8/208.0 kB 12.2 MB/s eta 0:00:01
#    ---------------------------------------- 208.0/208.0 kB 1.6 MB/s eta 0:00:00
# Downloading orjson-3.11.4-cp310-cp310-win_amd64.whl (131 kB)
#    ---------------------------------------- 0.0/131.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/131.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/131.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/131.6 kB ? eta -:--:--
#    ------------------------------------- -- 122.9/131.6 kB ? eta -:--:--
#    -------------------------------------- 131.6/131.6 kB 516.3 kB/s eta 0:00:00
# Using cached posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl (35 kB)
# Downloading pydantic-2.12.4-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.4 kB ? eta -:--:--
#    ---------------------------------------  460.8/463.4 kB ? eta -:--:--
#    ---------------------------------------  460.8/463.4 kB ? eta -:--:--
#    ---------------------------------------  460.8/463.4 kB ? eta -:--:--
#    ---------------------------------------- 463.4/463.4 kB 2.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp310-cp310-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.6/2.0 MB 17.5 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 13.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.8/2.0 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  2.0/2.0 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.1 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#    ---------------------------------------- 0.0/243.4 kB ? eta -:--:--
#    -------------------------------------- - 235.5/243.4 kB ? eta -:--:--
#    -------------------------------------- - 235.5/243.4 kB ? eta -:--:--
#    ---------------------------------------- 243.4/243.4 kB 2.5 MB/s eta 0:00:00
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Downloading torch-2.9.1-cp310-cp310-win_amd64.whl (111.0 MB)
#    ---------------------------------------- 0.0/111.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/111.0 MB 14.2 MB/s eta 0:00:08
#    ---------------------------------------- 1.1/111.0 MB 11.2 MB/s eta 0:00:10
#     --------------------------------------- 1.6/111.0 MB 11.0 MB/s eta 0:00:10
#     --------------------------------------- 2.1/111.0 MB 11.2 MB/s eta 0:00:10
#     --------------------------------------- 2.6/111.0 MB 11.1 MB/s eta 0:00:10
#    - -------------------------------------- 3.2/111.0 MB 10.7 MB/s eta 0:00:11
#    - -------------------------------------- 3.6/111.0 MB 10.1 MB/s eta 0:00:11
#    - -------------------------------------- 4.0/111.0 MB 10.6 MB/s eta 0:00:11
#    - -------------------------------------- 4.4/111.0 MB 10.5 MB/s eta 0:00:11
#    - -------------------------------------- 4.7/111.0 MB 10.0 MB/s eta 0:00:11
#    - -------------------------------------- 5.1/111.0 MB 9.9 MB/s eta 0:00:11
#    -- ------------------------------------- 5.7/111.0 MB 10.0 MB/s eta 0:00:11
#    -- ------------------------------------- 6.0/111.0 MB 9.8 MB/s eta 0:00:11
#    -- ------------------------------------- 6.4/111.0 MB 9.7 MB/s eta 0:00:11
#    -- ------------------------------------- 7.0/111.0 MB 9.7 MB/s eta 0:00:11
#    -- ------------------------------------- 7.2/111.0 MB 9.6 MB/s eta 0:00:11
#    -- ------------------------------------- 7.4/111.0 MB 9.1 MB/s eta 0:00:12
#    -- ------------------------------------- 7.6/111.0 MB 9.2 MB/s eta 0:00:12
#    -- ------------------------------------- 7.8/111.0 MB 8.8 MB/s eta 0:00:12
#    -- ------------------------------------- 8.1/111.0 MB 8.6 MB/s eta 0:00:12
#    --- ------------------------------------ 8.4/111.0 MB 8.5 MB/s eta 0:00:13
#    --- ------------------------------------ 8.7/111.0 MB 8.4 MB/s eta 0:00:13
#    --- ------------------------------------ 9.0/111.0 MB 8.3 MB/s eta 0:00:13
#    --- ------------------------------------ 9.1/111.0 MB 8.1 MB/s eta 0:00:13
#    --- ------------------------------------ 9.4/111.0 MB 8.1 MB/s eta 0:00:13
#    --- ------------------------------------ 9.9/111.0 MB 8.1 MB/s eta 0:00:13
#    --- ------------------------------------ 10.3/111.0 MB 8.1 MB/s eta 0:00:13
#    --- ------------------------------------ 10.9/111.0 MB 8.1 MB/s eta 0:00:13
#    ---- ----------------------------------- 11.4/111.0 MB 8.2 MB/s eta 0:00:13
#    ---- ----------------------------------- 11.9/111.0 MB 8.1 MB/s eta 0:00:13
#    ---- ----------------------------------- 12.4/111.0 MB 8.1 MB/s eta 0:00:13
#    ---- ----------------------------------- 12.8/111.0 MB 8.0 MB/s eta 0:00:13
#    ---- ----------------------------------- 13.0/111.0 MB 7.9 MB/s eta 0:00:13
#    ---- ----------------------------------- 13.3/111.0 MB 7.8 MB/s eta 0:00:13
#    ---- ----------------------------------- 13.4/111.0 MB 7.5 MB/s eta 0:00:13
#    ---- ----------------------------------- 13.6/111.0 MB 7.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 13.9/111.0 MB 7.4 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.2/111.0 MB 7.1 MB/s eta 0:00:14
#    ----- ---------------------------------- 14.6/111.0 MB 7.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 15.1/111.0 MB 7.3 MB/s eta 0:00:14
#    ----- ---------------------------------- 15.6/111.0 MB 7.4 MB/s eta 0:00:13
#    ----- ---------------------------------- 16.0/111.0 MB 7.3 MB/s eta 0:00:14
#    ----- ---------------------------------- 16.6/111.0 MB 7.4 MB/s eta 0:00:13
#    ------ --------------------------------- 16.9/111.0 MB 7.2 MB/s eta 0:00:14
#    ------ --------------------------------- 17.3/111.0 MB 7.2 MB/s eta 0:00:14
#    ------ --------------------------------- 17.6/111.0 MB 7.4 MB/s eta 0:00:13
#    ------ --------------------------------- 18.0/111.0 MB 7.7 MB/s eta 0:00:13
#    ------ --------------------------------- 18.4/111.0 MB 7.8 MB/s eta 0:00:12
#    ------ --------------------------------- 18.7/111.0 MB 7.7 MB/s eta 0:00:12
#    ------ --------------------------------- 19.0/111.0 MB 7.7 MB/s eta 0:00:12
#    ------- -------------------------------- 19.5/111.0 MB 7.9 MB/s eta 0:00:12
#    ------- -------------------------------- 20.0/111.0 MB 8.1 MB/s eta 0:00:12
#    ------- -------------------------------- 20.3/111.0 MB 8.1 MB/s eta 0:00:12
#    ------- -------------------------------- 20.8/111.0 MB 8.1 MB/s eta 0:00:12
#    ------- -------------------------------- 21.3/111.0 MB 8.0 MB/s eta 0:00:12
#    ------- -------------------------------- 21.8/111.0 MB 8.0 MB/s eta 0:00:12
#    ------- -------------------------------- 22.2/111.0 MB 8.0 MB/s eta 0:00:12
#    -------- ------------------------------- 22.6/111.0 MB 8.1 MB/s eta 0:00:11
#    -------- ------------------------------- 23.0/111.0 MB 8.0 MB/s eta 0:00:12
#    -------- ------------------------------- 23.3/111.0 MB 8.1 MB/s eta 0:00:11
#    -------- ------------------------------- 23.3/111.0 MB 8.1 MB/s eta 0:00:11
#    -------- ------------------------------- 23.3/111.0 MB 8.1 MB/s eta 0:00:11
#    -------- ------------------------------- 23.4/111.0 MB 7.2 MB/s eta 0:00:13
#    -------- ------------------------------- 24.8/111.0 MB 8.4 MB/s eta 0:00:11
#    -------- ------------------------------- 24.9/111.0 MB 8.2 MB/s eta 0:00:11
#    --------- ------------------------------ 25.1/111.0 MB 8.1 MB/s eta 0:00:11
#    --------- ------------------------------ 25.3/111.0 MB 8.0 MB/s eta 0:00:11
#    --------- ------------------------------ 25.5/111.0 MB 7.7 MB/s eta 0:00:12
#    --------- ------------------------------ 26.0/111.0 MB 7.6 MB/s eta 0:00:12
#    --------- ------------------------------ 26.4/111.0 MB 7.6 MB/s eta 0:00:12
#    --------- ------------------------------ 26.9/111.0 MB 7.5 MB/s eta 0:00:12
#    --------- ------------------------------ 27.5/111.0 MB 7.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 27.8/111.0 MB 7.9 MB/s eta 0:00:11
#    ---------- ----------------------------- 28.2/111.0 MB 7.8 MB/s eta 0:00:11
#    ---------- ----------------------------- 28.8/111.0 MB 8.0 MB/s eta 0:00:11
#    ---------- ----------------------------- 29.1/111.0 MB 7.9 MB/s eta 0:00:11
#    ---------- ----------------------------- 29.4/111.0 MB 8.0 MB/s eta 0:00:11
#    ---------- ----------------------------- 29.8/111.0 MB 8.0 MB/s eta 0:00:11
#    ---------- ----------------------------- 30.3/111.0 MB 8.0 MB/s eta 0:00:11
#    ----------- ---------------------------- 30.7/111.0 MB 8.0 MB/s eta 0:00:11
#    ----------- ---------------------------- 31.3/111.0 MB 7.9 MB/s eta 0:00:11
#    ----------- ---------------------------- 31.8/111.0 MB 8.0 MB/s eta 0:00:10
#    ----------- ---------------------------- 32.3/111.0 MB 8.1 MB/s eta 0:00:10
#    ----------- ---------------------------- 32.8/111.0 MB 8.1 MB/s eta 0:00:10
#    ----------- ---------------------------- 33.2/111.0 MB 8.1 MB/s eta 0:00:10
#    ------------ --------------------------- 33.6/111.0 MB 9.2 MB/s eta 0:00:09
#    ------------ --------------------------- 34.1/111.0 MB 9.0 MB/s eta 0:00:09
#    ------------ --------------------------- 34.6/111.0 MB 8.7 MB/s eta 0:00:09
#    ------------ --------------------------- 35.1/111.0 MB 8.7 MB/s eta 0:00:09
#    ------------ --------------------------- 35.5/111.0 MB 9.1 MB/s eta 0:00:09
#    ------------ --------------------------- 35.9/111.0 MB 9.2 MB/s eta 0:00:09
#    ------------- -------------------------- 36.4/111.0 MB 9.5 MB/s eta 0:00:08
#    ------------- -------------------------- 36.6/111.0 MB 9.6 MB/s eta 0:00:08
#    ------------- -------------------------- 36.8/111.0 MB 9.1 MB/s eta 0:00:09
#    ------------- -------------------------- 37.2/111.0 MB 9.0 MB/s eta 0:00:09
#    ------------- -------------------------- 37.6/111.0 MB 9.0 MB/s eta 0:00:09
#    ------------- -------------------------- 38.0/111.0 MB 8.7 MB/s eta 0:00:09
#    ------------- -------------------------- 38.1/111.0 MB 8.8 MB/s eta 0:00:09
#    ------------- -------------------------- 38.4/111.0 MB 8.7 MB/s eta 0:00:09
#    -------------- ------------------------- 39.0/111.0 MB 8.6 MB/s eta 0:00:09
#    -------------- ------------------------- 39.4/111.0 MB 8.8 MB/s eta 0:00:09
#    -------------- ------------------------- 39.9/111.0 MB 8.7 MB/s eta 0:00:09
#    -------------- ------------------------- 40.2/111.0 MB 8.6 MB/s eta 0:00:09
#    -------------- ------------------------- 40.5/111.0 MB 8.4 MB/s eta 0:00:09
#    -------------- ------------------------- 40.8/111.0 MB 8.4 MB/s eta 0:00:09
#    -------------- ------------------------- 41.3/111.0 MB 8.3 MB/s eta 0:00:09
#    -------------- ------------------------- 41.4/111.0 MB 8.2 MB/s eta 0:00:09
#    -------------- ------------------------- 41.6/111.0 MB 8.0 MB/s eta 0:00:09
#    --------------- ------------------------ 41.9/111.0 MB 7.8 MB/s eta 0:00:09
#    --------------- ------------------------ 42.3/111.0 MB 7.7 MB/s eta 0:00:09
#    --------------- ------------------------ 42.6/111.0 MB 7.7 MB/s eta 0:00:09
#    --------------- ------------------------ 43.0/111.0 MB 7.6 MB/s eta 0:00:09
#    --------------- ------------------------ 43.3/111.0 MB 7.6 MB/s eta 0:00:09
#    --------------- ------------------------ 43.7/111.0 MB 7.7 MB/s eta 0:00:09
#    --------------- ------------------------ 44.1/111.0 MB 7.6 MB/s eta 0:00:09
#    ---------------- ----------------------- 44.5/111.0 MB 7.6 MB/s eta 0:00:09
#    ---------------- ----------------------- 44.7/111.0 MB 7.4 MB/s eta 0:00:10
#    ---------------- ----------------------- 44.9/111.0 MB 7.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 45.3/111.0 MB 7.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 45.8/111.0 MB 7.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 45.8/111.0 MB 7.4 MB/s eta 0:00:09
#    ---------------- ----------------------- 46.2/111.0 MB 7.0 MB/s eta 0:00:10
#    ---------------- ----------------------- 46.3/111.0 MB 6.9 MB/s eta 0:00:10
#    ---------------- ----------------------- 46.5/111.0 MB 6.7 MB/s eta 0:00:10
#    ---------------- ----------------------- 46.7/111.0 MB 6.5 MB/s eta 0:00:10
#    ----------------- ---------------------- 47.2/111.0 MB 6.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 47.7/111.0 MB 6.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 48.2/111.0 MB 6.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 48.4/111.0 MB 6.8 MB/s eta 0:00:10
#    ----------------- ---------------------- 48.7/111.0 MB 6.7 MB/s eta 0:00:10
#    ----------------- ---------------------- 49.2/111.0 MB 6.5 MB/s eta 0:00:10
#    ----------------- ---------------------- 49.6/111.0 MB 6.6 MB/s eta 0:00:10
#    ------------------ --------------------- 50.0/111.0 MB 6.6 MB/s eta 0:00:10
#    ------------------ --------------------- 50.5/111.0 MB 6.7 MB/s eta 0:00:10
#    ------------------ --------------------- 50.8/111.0 MB 6.7 MB/s eta 0:00:10
#    ------------------ --------------------- 50.9/111.0 MB 6.4 MB/s eta 0:00:10
#    ------------------ --------------------- 51.4/111.0 MB 6.5 MB/s eta 0:00:10
#    ------------------ --------------------- 51.8/111.0 MB 6.7 MB/s eta 0:00:09
#    ------------------ --------------------- 52.2/111.0 MB 6.7 MB/s eta 0:00:09
#    ------------------ --------------------- 52.6/111.0 MB 6.8 MB/s eta 0:00:09
#    ------------------- -------------------- 53.3/111.0 MB 6.7 MB/s eta 0:00:09
#    ------------------- -------------------- 53.7/111.0 MB 6.7 MB/s eta 0:00:09
#    ------------------- -------------------- 54.4/111.0 MB 7.0 MB/s eta 0:00:09
#    ------------------- -------------------- 54.8/111.0 MB 7.0 MB/s eta 0:00:08
#    ------------------- -------------------- 55.3/111.0 MB 7.2 MB/s eta 0:00:08
#    -------------------- ------------------- 55.7/111.0 MB 7.1 MB/s eta 0:00:08
#    -------------------- ------------------- 56.3/111.0 MB 7.5 MB/s eta 0:00:08
#    -------------------- ------------------- 56.7/111.0 MB 7.8 MB/s eta 0:00:07
#    -------------------- ------------------- 57.4/111.0 MB 7.9 MB/s eta 0:00:07
#    -------------------- ------------------- 58.1/111.0 MB 8.1 MB/s eta 0:00:07
# ...
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------  111.0/111.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 111.0/111.0 MB 3.4 MB/s eta 0:00:00
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading transformers-4.57.1-py3-none-any.whl (12.0 MB)
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/12.0 MB 10.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.8/12.0 MB 8.4 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/12.0 MB 10.3 MB/s eta 0:00:02
#    ------ --------------------------------- 1.8/12.0 MB 10.5 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/12.0 MB 11.0 MB/s eta 0:00:01
#    --------- ------------------------------ 2.8/12.0 MB 9.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.2/12.0 MB 10.3 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.5/12.0 MB 10.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.8/12.0 MB 9.6 MB/s eta 0:00:01
#    -------------- ------------------------- 4.2/12.0 MB 9.0 MB/s eta 0:00:01
#    --------------- ------------------------ 4.8/12.0 MB 9.5 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/12.0 MB 9.1 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/12.0 MB 8.9 MB/s eta 0:00:01
#    ------------------ --------------------- 5.6/12.0 MB 8.8 MB/s eta 0:00:01
#    ------------------- -------------------- 5.9/12.0 MB 8.5 MB/s eta 0:00:01
#    --------------------- ------------------ 6.4/12.0 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.7/12.0 MB 8.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.2/12.0 MB 8.8 MB/s eta 0:00:01
#    ------------------------- -------------- 7.6/12.0 MB 8.7 MB/s eta 0:00:01
#    -------------------------- ------------- 7.8/12.0 MB 8.5 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/12.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/12.0 MB 8.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.6/12.0 MB 8.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.8/12.0 MB 7.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.9/12.0 MB 7.6 MB/s eta 0:00:01
#    ------------------------------- -------- 9.4/12.0 MB 7.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.8/12.0 MB 7.8 MB/s eta 0:00:01
#    --------------------------------- ------ 10.1/12.0 MB 7.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.4/12.0 MB 7.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.6/12.0 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.0/12.0 MB 7.4 MB/s eta 0:00:01
#    ------------------------------------- -- 11.3/12.0 MB 7.3 MB/s eta 0:00:01
#    -------------------------------------- - 11.7/12.0 MB 7.3 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------  12.0/12.0 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.0/12.0 MB 6.4 MB/s eta 0:00:00
# Downloading huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
#    ---------------------------------------- 0.0/566.1 kB ? eta -:--:--
#    ------------------ --------------------- 256.0/566.1 kB 7.7 MB/s eta 0:00:01
#    ------------------------------- -------- 440.3/566.1 kB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  563.2/566.1 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  563.2/566.1 kB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 566.1/566.1 kB 2.7 MB/s eta 0:00:00
# Downloading typer-0.20.0-py3-none-any.whl (47 kB)
#    ---------------------------------------- 0.0/47.0 kB ? eta -:--:--
#    ---------------------------------- ----- 41.0/47.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/47.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 41.0/47.0 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 47.0/47.0 kB 213.9 kB/s eta 0:00:00
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.1 kB ? eta -:--:--
#    ------------------------------------ --- 61.4/68.1 kB ? eta -:--:--
#    ------------------------------------ --- 61.4/68.1 kB ? eta -:--:--
#    ---------------------------------------- 68.1/68.1 kB 615.6 kB/s eta 0:00:00
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
#    ---------------------------------------- 0.0/108.3 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/108.3 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/108.3 kB ? eta -:--:--
#    ---------------------------------------- 108.3/108.3 kB 1.2 MB/s eta 0:00:00
# Using cached durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading fsspec-2025.10.0-py3-none-any.whl (200 kB)
#    ---------------------------------------- 0.0/201.0 kB ? eta -:--:--
#    ------------------------------------- - 194.6/201.0 kB 12.3 MB/s eta 0:00:01
#    ------------------------------------- - 194.6/201.0 kB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 201.0/201.0 kB 1.7 MB/s eta 0:00:00
# Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#    ---------------------------------------- 0.0/223.1 kB ? eta -:--:--
#    ------------------------------------- - 215.0/223.1 kB 12.8 MB/s eta 0:00:01
#    ------------------------------------- - 215.0/223.1 kB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 223.1/223.1 kB 1.9 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.72.0-py3-none-any.whl (297 kB)
#    ---------------------------------------- 0.0/297.5 kB ? eta -:--:--
#    --------------------------------------  297.0/297.5 kB 19.1 MB/s eta 0:00:01
#    --------------------------------------  297.0/297.5 kB 19.1 MB/s eta 0:00:01
#    --------------------------------------  297.0/297.5 kB 19.1 MB/s eta 0:00:01
#    ---------------------------------------- 297.5/297.5 kB 1.8 MB/s eta 0:00:00
# Downloading httptools-0.7.1-cp310-cp310-win_amd64.whl (86 kB)
#    ---------------------------------------- 0.0/86.2 kB ? eta -:--:--
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    -------------------------------------- - 81.9/86.2 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 86.2/86.2 kB 147.2 kB/s eta 0:00:00
# Using cached importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.7 MB 11.5 MB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 7.3 MB/s eta 0:00:00
# Downloading protobuf-6.33.1-cp310-abi3-win_amd64.whl (436 kB)
#    ---------------------------------------- 0.0/436.9 kB ? eta -:--:--
#    --------------------------------------  430.1/436.9 kB 13.1 MB/s eta 0:00:01
#    --------------------------------------  430.1/436.9 kB 13.1 MB/s eta 0:00:01
#    ---------------------------------------- 436.9/436.9 kB 3.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Downloading regex-2025.11.3-cp310-cp310-win_amd64.whl (277 kB)
#    ---------------------------------------- 0.0/277.7 kB ? eta -:--:--
#    --------------------------------------  276.5/277.7 kB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 277.7/277.7 kB 2.8 MB/s eta 0:00:00
# Downloading safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
#    ---------------------------------------- 0.0/341.4 kB ? eta -:--:--
#    --------------------------------------  337.9/341.4 kB 10.2 MB/s eta 0:00:01
#    --------------------------------------  337.9/341.4 kB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 341.4/341.4 kB 4.2 MB/s eta 0:00:00
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading watchfiles-1.1.1-cp310-cp310-win_amd64.whl (287 kB)
#    ---------------------------------------- 0.0/287.5 kB ? eta -:--:--
#    --------------------------------------  286.7/287.5 kB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 287.5/287.5 kB 4.4 MB/s eta 0:00:00
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
#    ---------------------------------------- 0.0/176.8 kB ? eta -:--:--
#    ---------------------------------------  174.1/176.8 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 176.8/176.8 kB 2.1 MB/s eta 0:00:00
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pypika, mpmath, flatbuffers, durationpy, zipp, websockets, typing-extensions, tqdm, tenacity, sympy, shellingham, safetensors, regex, python-dotenv, pyreadline3, pyproject_hooks, pybase64, pyasn1, protobuf, orjson, oauthlib, networkx, mmh3, mdurl, lxml, jiter, importlib-resources, httptools, fsspec, filelock, distro, click, cachetools, bcrypt, backoff, annotated-types, uvicorn, typing-inspection, torch, rsa, requests-oauthlib, pydantic-core, pyasn1-modules, posthog, opentelemetry-proto, markdown-it-py, importlib-metadata, humanfriendly, huggingface-hub, grpcio, googleapis-common-protos, build, watchfiles, tokenizers, rich, pydantic, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, google-auth, coloredlogs, typer, transformers, opentelemetry-semantic-conventions, openai, onnxruntime, kubernetes, sentence-transformers, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.0
#     Uninstalling typing_extensions-4.12.0:
#       Successfully uninstalled typing_extensions-4.12.0
# Successfully installed annotated-types-0.7.0 backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 cachetools-6.2.2 chromadb-1.3.5 click-8.3.1 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 filelock-3.20.0 flatbuffers-25.9.23 fsspec-2025.10.0 google-auth-2.43.0 googleapis-common-protos-1.72.0 grpcio-1.76.0 httptools-0.7.1 huggingface-hub-0.36.0 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 jiter-0.12.0 kubernetes-34.1.0 lxml-6.0.2 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 mpmath-1.3.0 networkx-3.4.2 oauthlib-3.3.1 onnxruntime-1.23.2 openai-2.8.1 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 orjson-3.11.4 posthog-5.4.0 protobuf-6.33.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pybase64-1.4.2 pydantic-2.12.4 pydantic-core-2.41.5 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 python-dotenv-1.2.1 regex-2025.11.3 requests-oauthlib-2.0.0 rich-14.2.0 rsa-4.9.1 safetensors-0.7.0 sentence-transformers-5.1.2 shellingham-1.5.4 sympy-1.14.0 tenacity-9.1.2 tokenizers-0.22.1 torch-2.9.1 tqdm-4.67.1 transformers-4.57.1 typer-0.20.0 typing-extensions-4.15.0 typing-inspection-0.4.2 uvicorn-0.38.0 watchfiles-1.1.1 websockets-15.0.1 zipp-3.23.0
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: C:\Users\Dzaki\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI
from datetime import datetime
import json
import chromadb
from chromadb.utils import embedding_functions
import time
import re

class BBCANewsAnalyzer:
    def __init__(self, openai_api_key):
        """Initialize sistem dengan OpenAI API dan ChromaDB untuk RAG"""

        # Setup OpenAI
        self.client = OpenAI(
            base_url="https://openrouter.ai/api/v1",
            api_key=openai_api_key)
        self.model = "openai/gpt-oss-20b:free"

        # Setup ChromaDB untuk Vector Store (RAG)
        self.chroma_client = chromadb.Client()
        self.embedding_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
            model_name="all-MiniLM-L6-v2"
        )

        # Buat/reset collection
        try:
            self.chroma_client.delete_collection("bbca_news_db")
        except:
            pass

        self.collection = self.chroma_client.create_collection(
            name="bbca_news_db",
            embedding_function=self.embedding_fn
        )

        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
        }

        # Knowledge Base BBCA untuk RAG
        self.bbca_knowledge = {
            "positive_indicators": [
                "pertumbuhan laba", "kenaikan profit", "dividen naik",
                "ekspansi digital", "pertumbuhan kredit", "NPL turun",
                "akuisisi", "inovasi", "market share naik", "CAR kuat"
            ],
            "negative_indicators": [
                "penurunan laba", "profit turun", "NPL naik",
                "kredit macet", "denda", "sanksi", "gugatan",
                "PHK", "skandal", "fraud", "penurunan kredit"
            ],
            "context": """
            Bank Central Asia (BBCA) adalah bank swasta terbesar di Indonesia
            dengan fokus pada segmen retail dan UMKM. Kinerja saham BBCA
            sangat dipengaruhi oleh pertumbuhan kredit, kualitas aset (NPL),
            profitabilitas (ROE, NIM), dan digitalisasi layanan.
            """
        }

    def scrape_cnbc_news(self, base_search_url, max_articles=10, max_pages=3):
        """
        Scrape berita dari CNBC Indonesia dengan pagination
        Args:
            base_search_url: URL dasar tanpa parameter page
            max_articles: Jumlah maksimal artikel yang akan di-scrape
            max_pages: Jumlah maksimal halaman yang akan di-scrape
        """
        print(f"\n{'='*80}")
        print(f"🔍 Memulai scraping berita BBCA dari CNBC Indonesia")
        print(f"📄 Max artikel: {max_articles} | Max halaman: {max_pages}")
        print(f"{'='*80}\n")

        articles = []
        article_count = 0

        for page in range(1, max_pages + 1):
            if article_count >= max_articles:
                break

            # URL untuk setiap page
            if page == 1:
                search_url = base_search_url
            else:
                # Tambahkan parameter page
                separator = "&" if "?" in base_search_url else "?"
                search_url = f"{base_search_url}{separator}page={page}"

            print(f"🌐 Scraping halaman {page}: {search_url}")

            try:
                response = requests.get(search_url, headers=self.headers, timeout=15)
                response.raise_for_status()
                soup = BeautifulSoup(response.content, 'html.parser')

                # Cari artikel dengan berbagai selector (sesuai struktur CNBC Indonesia)
                news_items = soup.find_all('article', class_='list')

                # Coba selector alternatif
                if not news_items:
                    news_items = soup.find_all('div', class_='list_article')

                if not news_items:
                    news_items = soup.find_all('article')

                if not news_items:
                    news_items = soup.find_all('div', class_='media__text')

                if not news_items:
                    print(f"   ⚠️  Tidak ada artikel di halaman {page}")
                    print(f"   💡 Debug: Coba cek struktur HTML secara manual\n")
                    break

                print(f"   ✅ Ditemukan {len(news_items)} artikel di halaman {page}\n")

                for item in news_items:
                    if article_count >= max_articles:
                        break

                    try:
                        # Extract title dan link (sesuai struktur CNBC Indonesia)
                        title_elem = item.find('h2') or item.find('h3') or item.find('h4') or item.find('a')
                        link_elem = None
                        title = ""
                        link = ""

                        # Coba ambil dari h2/h3/h4 yang berisi tag <a>
                        if title_elem:
                            link_elem = title_elem.find('a')
                            if link_elem:
                                title = link_elem.get_text(strip=True)
                                link = link_elem.get('href', '')
                            else:
                                title = title_elem.get_text(strip=True)

                        # Jika belum dapat, coba langsung cari tag <a>
                        if not title or not link:
                            link_elem = item.find('a', href=True)
                            if link_elem:
                                title = link_elem.get_text(strip=True)
                                link = link_elem.get('href', '')

                        # Skip jika tidak ada title atau link
                        if not title or not link:
                            continue

                        # Pastikan link lengkap
                        if not link.startswith('http'):
                            base_url = "https://www.cnbcindonesia.com"
                            link = base_url + link

                        # Extract tanggal
                        date_elem = item.find('span', class_='date') or item.find('time')
                        date = date_elem.get_text(strip=True) if date_elem else datetime.now().strftime('%d %B %Y')

                        # Extract kategori (opsional)
                        category_elem = item.find('span', class_='label') or item.find('div', class_='kategori')
                        category = category_elem.get_text(strip=True) if category_elem else ""

                        # Extract deskripsi singkat (opsional)
                        desc_elem = item.find('p') or item.find('div', class_='desc')
                        description = desc_elem.get_text(strip=True) if desc_elem else ""

                        article_count += 1
                        print(f"📰 [{article_count}] {title[:70]}...")

                        # Ambil konten artikel
                        content = self._extract_article_content(link)

                        article = {
                            'id': f"article_{article_count}_{int(time.time())}",
                            'title': title,
                            'link': link,
                            'content': content,
                            'date': date,
                            'category': category,
                            'description': description,
                            'page': page,
                            'scraped_at': datetime.now().isoformat()
                        }

                        articles.append(article)

                        # Simpan ke Vector DB (RAG)
                        self._store_to_vectordb(article)

                        print(f"   ✅ Success | Konten: {len(content)} chars | Kategori: {category or 'N/A'}\n")
                        time.sleep(1)  # Rate limiting

                    except Exception as e:
                        print(f"   ⚠️  Error: {str(e)}\n")
                        continue

                # Delay antar halaman
                if page < max_pages and article_count < max_articles:
                    print(f"⏳ Menunggu sebelum ke halaman berikutnya...\n")
                    time.sleep(2)

            except Exception as e:
                print(f"❌ Error saat scraping halaman {page}: {str(e)}\n")
                continue

        print(f"\n✅ Total artikel berhasil di-scrape: {len(articles)}")
        return articles

    def _extract_article_content(self, url):
        """Extract konten artikel dari URL"""
        try:
            response = requests.get(url, headers=self.headers, timeout=15)
            soup = BeautifulSoup(response.content, 'html.parser')

            # Coba berbagai selector untuk konten
            selectors = [
                {'name': 'div', 'class': 'detail_text'},
                {'name': 'div', 'class': 'detail__body'},
                {'name': 'div', 'class': 'article__body'},
                {'name': 'article', 'class': None}
            ]

            content = ""
            for selector in selectors:
                content_div = soup.find(selector['name'], class_=selector['class'])
                if content_div:
                    paragraphs = content_div.find_all('p')
                    content = ' '.join([p.get_text(strip=True) for p in paragraphs])
                    if content:
                        break

            # Bersihkan dan limit panjang
            content = re.sub(r'\s+', ' ', content)
            return content[:5000]  # Limit 5000 karakter

        except Exception as e:
            print(f"      ⚠️  Error extract konten: {str(e)}")
            return ""

    def _store_to_vectordb(self, article):
        """Simpan artikel ke Vector Database (RAG)"""
        try:
            # Gabungkan title dan content untuk embedding
            full_text = f"{article['title']} {article['content']}"

            self.collection.add(
                documents=[full_text],
                metadatas=[{
                    'title': article['title'],
                    'link': article['link'],
                    'date': article['date']
                }],
                ids=[article['id']]
            )
        except Exception as e:
            print(f"      ⚠️  Error simpan ke vector DB: {str(e)}")

    def _retrieve_relevant_context(self, query, n_results=3):
        """Retrieve konteks relevan dari Vector DB (RAG)"""
        try:
            results = self.collection.query(
                query_texts=[query],
                n_results=min(n_results, self.collection.count())
            )

            if not results['documents'] or not results['documents'][0]:
                return ""

            # Gabungkan dokumen relevan
            contexts = []
            for doc, metadata in zip(results['documents'][0], results['metadatas'][0]):
                contexts.append(f"Berita terkait: {metadata['title']}\n{doc[:300]}...\n")

            return "\n".join(contexts)

        except Exception as e:
            print(f"⚠️  Error retrieve context: {str(e)}")
            return ""

    def analyze_sentiment_cot(self, article):
        """
        Analisis sentimen dengan Chain of Thought (CoT) menggunakan OpenAI
        """
        print(f"\n{'─'*80}")
        print(f"🤖 Menganalisis: {article['title'][:60]}...")
        print(f"{'─'*80}")

        # Retrieve konteks relevan (RAG)
        relevant_context = self._retrieve_relevant_context(article['title'], n_results=3)

        # Chain of Thought Prompt
        cot_prompt = f"""
Kamu adalah seorang analis saham profesional yang ahli dalam menganalisis sentimen berita terhadap saham BBCA (Bank Central Asia).

=== KNOWLEDGE BASE BBCA ===
{self.bbca_knowledge['context']}

Indikator Positif: {', '.join(self.bbca_knowledge['positive_indicators'])}
Indikator Negatif: {', '.join(self.bbca_knowledge['negative_indicators'])}

=== KONTEKS BERITA RELEVAN (RAG) ===
{relevant_context if relevant_context else "Tidak ada konteks tambahan dari database"}

=== BERITA YANG AKAN DIANALISIS ===
Judul: {article['title']}
Tanggal: {article['date']}
Konten: {article['content'][:3000] if article['content'] else "Konten tidak tersedia"}

=== CHAIN OF THOUGHT ANALYSIS ===
Lakukan analisis bertahap (step-by-step) dengan struktur berikut:

**STEP 1 - IDENTIFIKASI INFORMASI KUNCI**
- Ekstrak fakta-fakta penting dari berita
- Identifikasi angka, persentase, atau data kuantitatif
- Pisahkan fakta dari opini atau spekulasi
- List minimal 3-5 poin informasi kunci

**STEP 2 - ANALISIS DAMPAK FUNDAMENTAL**
- Bagaimana berita ini mempengaruhi kinerja keuangan BBCA?
- Apakah ada dampak pada revenue, profit margin, atau asset quality?
- Bagaimana ini mempengaruhi posisi kompetitif BBCA?
- Analisis dampak jangka pendek vs jangka panjang

**STEP 3 - EVALUASI SENTIMEN PASAR**
- Bagaimana investor retail kemungkinan bereaksi?
- Bagaimana investor institusional mungkin merespons?
- Apakah berita ini bisa memicu buying atau selling pressure?
- Bandingkan dengan berita serupa di masa lalu

**STEP 4 - KONTEKS INDUSTRI & MAKRO**
- Bagaimana posisi berita ini dalam konteks sektor perbankan?
- Apakah ada implikasi regulasi atau kebijakan?
- Bagaimana kondisi ekonomi makro mempengaruhi interpretasi?

**STEP 5 - KESIMPULAN & SCORING**
- Sintesis dari semua analisis di atas
- Tentukan sentimen final dengan confidence level
- Berikan skor numerik dan rekomendasi

=== OUTPUT FORMAT ===
Berikan output dalam format JSON berikut (HANYA JSON, tanpa teks lain):

{{
  "chain_of_thought": {{
    "step1_informasi_kunci": [
      "poin informasi 1",
      "poin informasi 2",
      "poin informasi 3"
    ],
    "step2_dampak_fundamental": "analisis detail dampak fundamental",
    "step3_sentimen_pasar": "analisis ekspektasi reaksi pasar",
    "step4_konteks_industri": "analisis konteks industri dan makro",
    "step5_reasoning_final": "reasoning untuk kesimpulan akhir"
  }},
  "sentimen": "POSITIF atau NEGATIF atau NETRAL",
  "confidence": "TINGGI atau SEDANG atau RENDAH",
  "skor": 0,
  "dampak_harga": "BULLISH atau BEARISH atau NETRAL",
  "time_horizon": "JANGKA_PENDEK atau JANGKA_PANJANG atau KEDUANYA",
  "rekomendasi": "BUY atau HOLD atau SELL",
  "key_factors": ["faktor1", "faktor2", "faktor3"],
  "ringkasan_eksekutif": "ringkasan 2-3 kalimat untuk investor"
}}

PENTING:
- Skor dari -10 (sangat negatif) hingga +10 (sangat positif)
- Berikan HANYA JSON tanpa markdown atau penjelasan tambahan
- Pastikan analisis objektif dan berbasis data
"""

        try:
            # Generate analisis dari OpenAI
            response = self.client.chat.completions.create(
                model=self.model,
                messages=[
                    {"role": "system", "content": "Kamu adalah analis saham profesional yang ahli dalam analisis sentimen berita. Berikan output dalam format JSON yang valid."},
                    {"role": "user", "content": cot_prompt}
                ],
                temperature=0.3,
                response_format={"type": "json_object"}
            )

            result_text = response.choices[0].message.content.strip()

            # Parse JSON
            analysis = json.loads(result_text)

            # Tampilkan hasil
            print(f"\n📊 Hasil Analisis:")
            print(f"   Sentimen: {analysis['sentimen']} ({analysis['confidence']})")
            print(f"   Skor: {analysis['skor']}/10")
            print(f"   Dampak: {analysis['dampak_harga']}")
            print(f"   Rekomendasi: {analysis['rekomendasi']}")
            print(f"   Ringkasan: {analysis['ringkasan_eksekutif']}")

            return analysis

        except json.JSONDecodeError as e:
            print(f"\n❌ Error: Gagal parse JSON response")
            print(f"Response: {result_text[:300]}...")
            return self._create_error_response("JSON parse error", result_text)

        except Exception as e:
            print(f"\n❌ Error analisis: {str(e)}")
            return self._create_error_response(str(e))

    def _create_error_response(self, error_msg, raw_response=""):
        """Buat response error yang konsisten"""
        return {
            "sentimen": "ERROR",
            "confidence": "RENDAH",
            "skor": 0,
            "error": error_msg,
            "raw_response": raw_response[:500]
        }

    def analyze_all_articles(self, articles):
        """Analisis semua artikel"""
        print(f"\n\n{'='*80}")
        print(f"🚀 MEMULAI ANALISIS {len(articles)} ARTIKEL")
        print(f"{'='*80}")

        results = []
        for idx, article in enumerate(articles, 1):
            print(f"\n[{idx}/{len(articles)}]")

            analysis = self.analyze_sentiment_cot(article)

            # Tambahkan info artikel
            analysis['article_info'] = {
                'title': article['title'],
                'link': article['link'],
                'date': article['date']
            }

            results.append(analysis)

            # Rate limiting
            if idx < len(articles):
                time.sleep(2)

        return results

    def generate_daily_recommendation(self, analyses):
        """
        Generate rekomendasi harian apakah bagus untuk membeli saham BBCA hari ini
        """
        print(f"\n\n{'='*80}")
        print(f"🎯 MENGHASILKAN REKOMENDASI HARIAN UNTUK MEMBELI SAHAM BBCA")
        print(f"{'='*80}")

        # Filter error
        valid_analyses = [a for a in analyses if a.get('sentimen') != 'ERROR']

        if not valid_analyses:
            print("\n❌ Tidak ada analisis valid untuk membuat rekomendasi")
            return None

        # Persiapkan summary untuk AI
        summary_data = {
            "total_berita": len(valid_analyses),
            "positif": sum(1 for a in valid_analyses if a['sentimen'] == 'POSITIF'),
            "negatif": sum(1 for a in valid_analyses if a['sentimen'] == 'NEGATIF'),
            "netral": sum(1 for a in valid_analyses if a['sentimen'] == 'NETRAL'),
            "avg_score": sum(a.get('skor', 0) for a in valid_analyses) / len(valid_analyses),
            "recent_news": []
        }

        # Ambil 5 berita terbaru dengan analisisnya
        for analysis in valid_analyses[:5]:
            info = analysis.get('article_info', {})
            summary_data['recent_news'].append({
                "title": info.get('title', ''),
                "date": info.get('date', ''),
                "sentimen": analysis.get('sentimen', ''),
                "skor": analysis.get('skor', 0),
                "dampak_harga": analysis.get('dampak_harga', ''),
                "rekomendasi": analysis.get('rekomendasi', ''),
                "ringkasan": analysis.get('ringkasan_eksekutif', '')
            })

        # Prompt untuk rekomendasi harian
        recommendation_prompt = f"""
Kamu adalah seorang financial advisor profesional yang membantu investor retail membuat keputusan investasi harian.

=== DATA ANALISIS SENTIMEN BERITA BBCA HARI INI ===
Tanggal: {datetime.now().strftime('%d %B %Y')}

**Statistik Overall:**
- Total Berita Dianalisis: {summary_data['total_berita']}
- Berita Positif: {summary_data['positif']} ({summary_data['positif']/summary_data['total_berita']*100:.1f}%)
- Berita Negatif: {summary_data['negatif']} ({summary_data['negatif']/summary_data['total_berita']*100:.1f}%)
- Berita Netral: {summary_data['netral']} ({summary_data['netral']/summary_data['total_berita']*100:.1f}%)
- Rata-rata Sentiment Score: {summary_data['avg_score']:.2f}/10

**5 Berita Terbaru dan Analisisnya:**
{json.dumps(summary_data['recent_news'], indent=2, ensure_ascii=False)}

=== TUGAS ANDA ===
Berdasarkan analisis sentimen berita di atas, berikan rekomendasi kepada investor:

**APAKAH HARI INI WAKTU YANG BAGUS UNTUK MEMBELI SAHAM BBCA?**

Pertimbangkan faktor-faktor berikut:
1. **Momentum Sentimen**: Apakah sentimen overall positif/negatif/mixed?
2. **Timing**: Apakah ada berita baru yang signifikan yang bisa menggerakkan harga?
3. **Risk/Reward**: Apakah risk saat ini seimbang dengan potential reward?
4. **Trend**: Apakah ada pola yang menunjukkan trend bullish atau bearish?
5. **Katalog Events**: Adakah event/berita penting yang perlu diperhatikan?

=== OUTPUT FORMAT ===
Berikan output dalam format JSON berikut:

{{
  "tanggal_analisis": "{datetime.now().strftime('%d %B %Y')}",
  "rekomendasi_harian": "BELI SEKARANG atau TUNGGU DULU atau HINDARI",
  "confidence_level": "SANGAT TINGGI atau TINGGI atau SEDANG atau RENDAH",
  "skor_investabilitas": 0,
  "reasoning": {{
    "sentimen_overview": "ringkasan sentimen keseluruhan",
    "momentum_analisis": "analisis momentum saat ini",
    "risk_assessment": "penilaian risiko investasi",
    "catalyst_check": "ada/tidaknya catalyst positif/negatif"
  }},
  "action_plan": {{
    "jika_beli": "kapan timing terbaik untuk entry",
    "target_price": "estimasi target harga (jika ada)",
    "stop_loss": "rekomendasi stop loss level",
    "holding_period": "rekomendasi holding period"
  }},
  "key_points": [
    "poin penting 1",
    "poin penting 2",
    "poin penting 3"
  ],
  "warnings": [
    "peringatan atau risiko yang perlu diperhatikan"
  ],
  "kesimpulan": "kesimpulan final dalam 2-3 kalimat yang jelas dan actionable"
}}

PENTING:
- Skor investabilitas dari 0-100 (0=sangat tidak layak, 100=sangat layak)
- Rekomendasi harus jelas: BELI SEKARANG / TUNGGU DULU / HINDARI
- Berikan reasoning yang objektif dan berbasis data
- Sebutkan risiko yang perlu diwaspadai
- Output HANYA JSON tanpa markdown
"""

        try:
            # Generate rekomendasi dari OpenAI
            print("🤖 Memproses rekomendasi harian dengan AI...")

            response = self.client.chat.completions.create(
                model=self.model,
                messages=[
                    {"role": "system", "content": "Kamu adalah financial advisor profesional yang memberikan rekomendasi investasi berbasis data. Output harus dalam format JSON yang valid."},
                    {"role": "user", "content": recommendation_prompt}
                ],
                temperature=0.2,
                response_format={"type": "json_object"}
            )

            result_text = response.choices[0].message.content.strip()
            recommendation = json.loads(result_text)

            # Tampilkan hasil
            print(f"\n{'='*80}")
            print(f"💡 REKOMENDASI HARIAN UNTUK MEMBELI SAHAM BBCA")
            print(f"{'='*80}")
            print(f"📅 Tanggal: {recommendation['tanggal_analisis']}")
            print(f"\n🎯 REKOMENDASI: {recommendation['rekomendasi_harian']}")
            print(f"📊 Skor Investabilitas: {recommendation['skor_investabilitas']}/100")
            print(f"🔒 Confidence Level: {recommendation['confidence_level']}")

            print(f"\n💭 REASONING:")
            reasoning = recommendation['reasoning']
            print(f"   • Sentimen: {reasoning['sentimen_overview']}")
            print(f"   • Momentum: {reasoning['momentum_analisis']}")
            print(f"   • Risk: {reasoning['risk_assessment']}")
            print(f"   • Catalyst: {reasoning['catalyst_check']}")

            print(f"\n📋 ACTION PLAN:")
            action = recommendation['action_plan']
            for key, value in action.items():
                print(f"   • {key.replace('_', ' ').title()}: {value}")

            print(f"\n🔑 KEY POINTS:")
            for point in recommendation['key_points']:
                print(f"   ✓ {point}")

            print(f"\n⚠️  WARNINGS:")
            for warning in recommendation['warnings']:
                print(f"   ! {warning}")

            print(f"\n💡 KESIMPULAN:")
            print(f"   {recommendation['kesimpulan']}")

            print(f"\n{'='*80}")

            return recommendation

        except Exception as e:
            print(f"\n❌ Error generate rekomendasi: {str(e)}")
            return None

    def generate_report(self, analyses):
        """Generate laporan komprehensif"""
        print(f"\n\n{'='*80}")
        print(f"📊 LAPORAN ANALISIS SENTIMEN SAHAM BBCA")
        print(f"{'='*80}")
        print(f"Waktu: {datetime.now().strftime('%d %B %Y, %H:%M:%S')}")

        # Filter error
        valid_analyses = [a for a in analyses if a.get('sentimen') != 'ERROR']

        if not valid_analyses:
            print("\n❌ Tidak ada analisis valid")
            return None

        # Statistik
        total = len(valid_analyses)
        positif = sum(1 for a in valid_analyses if a['sentimen'] == 'POSITIF')
        negatif = sum(1 for a in valid_analyses if a['sentimen'] == 'NEGATIF')
        netral = sum(1 for a in valid_analyses if a['sentimen'] == 'NETRAL')

        avg_score = sum(a.get('skor', 0) for a in valid_analyses) / total

        print(f"\n📈 RINGKASAN STATISTIK")
        print(f"{'─'*80}")
        print(f"Total Berita Dianalisis: {total}")
        print(f"  ✅ Positif: {positif} ({positif/total*100:.1f}%)")
        print(f"  ⚠️  Negatif: {negatif} ({negatif/total*100:.1f}%)")
        print(f"  ➖ Netral: {netral} ({netral/total*100:.1f}%)")
        print(f"Rata-rata Skor: {avg_score:.2f}/10")

        # Sentimen keseluruhan
        if positif > negatif and avg_score > 2:
            overall = "POSITIF ✅"
            recommendation = "Outlook positif untuk BBCA dalam jangka pendek"
        elif negatif > positif and avg_score < -2:
            overall = "NEGATIF ⚠️"
            recommendation = "Perlu perhatian, ada beberapa isu negatif"
        else:
            overall = "NETRAL/MIXED ➖"
            recommendation = "Sentimen beragam, perlu analisis lebih dalam"

        print(f"\n🎯 SENTIMEN KESELURUHAN: {overall}")
        print(f"💡 Rekomendasi: {recommendation}")

        # Detail per artikel
        print(f"\n📰 DETAIL ANALISIS PER ARTIKEL")
        print(f"{'='*80}")

        for idx, analysis in enumerate(valid_analyses, 1):
            info = analysis.get('article_info', {})
            cot = analysis.get('chain_of_thought', {})

            print(f"\n[{idx}] {info.get('title', 'N/A')}")
            print(f"{'─'*80}")
            print(f"📅 Tanggal: {info.get('date', 'N/A')}")
            print(f"📊 Sentimen: {analysis['sentimen']} | Confidence: {analysis['confidence']} | Skor: {analysis['skor']}/10")
            print(f"📈 Dampak: {analysis.get('dampak_harga', 'N/A')} | Horizon: {analysis.get('time_horizon', 'N/A')}")
            print(f"💼 Rekomendasi: {analysis.get('rekomendasi', 'N/A')}")
            print(f"\n💡 Ringkasan: {analysis.get('ringkasan_eksekutif', 'N/A')}")
            print(f"\n🔗 Link: {info.get('link', 'N/A')}")

            if cot:
                print(f"\n🧠 Chain of Thought Reasoning:")
                if cot.get('step1_informasi_kunci'):
                    print(f"   • Info Kunci: {', '.join(cot['step1_informasi_kunci'][:3])}")

        print(f"\n{'='*80}")

        # Prepare data untuk export
        report = {
            'timestamp': datetime.now().isoformat(),
            'summary': {
                'total_articles': total,
                'positif': positif,
                'negatif': negatif,
                'netral': netral,
                'avg_score': round(avg_score, 2),
                'overall_sentiment': overall,
                'recommendation': recommendation
            },
            'analyses': valid_analyses
        }

        return report

    def save_report(self, report, daily_recommendation=None, filename=None):
        """Simpan laporan ke file JSON"""
        if not report:
            print("Tidak ada laporan untuk disimpan")
            return

        if not filename:
            filename = f"bbca_sentiment_report_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"

        try:
            # Tambahkan rekomendasi harian ke report
            if daily_recommendation:
                report['daily_recommendation'] = daily_recommendation

            with open(filename, 'w', encoding='utf-8') as f:
                json.dump(report, f, ensure_ascii=False, indent=2)

            print(f"\n💾 Laporan disimpan: {filename}")
            print(f"📁 Lokasi: {filename}")

        except Exception as e:
            print(f"❌ Error menyimpan laporan: {str(e)}")


def main():
    """Main execution function"""
    print("="*80)
    print("🏦 BBCA STOCK NEWS SENTIMENT ANALYZER")
    print("📊 dengan RAG & Chain of Thought + Daily Recommendation")
    print("🤖 Powered by OpenAI GPT-4")
    print("="*80)

    # === KONFIGURASI ===
    OPENAI_API_KEY = "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"  # ← Ganti dengan API key Anda

    # URL pencarian BBCA di CNBC Indonesia
    SEARCH_URL = "https://www.cnbcindonesia.com/search?query=bbca"

    MAX_ARTICLES = 25  # Jumlah artikel yang akan dianalisis
    MAX_PAGES = 5      # Jumlah halaman yang akan di-scrape

    # Validasi API key
    if OPENAI_API_KEY == "YOUR_OPENAI_API_KEY_HERE":
        print("\n❌ ERROR: Silakan ganti OPENAI_API_KEY dengan API key Anda!")
        print("Dapatkan API key di: https://platform.openai.com/api-keys")
        return

    try:
        # Initialize analyzer
        analyzer = BBCANewsAnalyzer(OPENAI_API_KEY)

        # Scrape berita
        articles = analyzer.scrape_cnbc_news(
            base_search_url=SEARCH_URL,
            max_articles=MAX_ARTICLES,
            max_pages=MAX_PAGES
        )

        if not articles:
            print("\n❌ Tidak ada artikel yang berhasil di-scrape")
            return

        # Analisis semua artikel
        analyses = analyzer.analyze_all_articles(articles)

        # Generate laporan
        report = analyzer.generate_report(analyses)

        # === FITUR BARU: Generate Rekomendasi Harian ===
        daily_recommendation = analyzer.generate_daily_recommendation(analyses)

        # Simpan laporan dengan rekomendasi harian
        if report:
            analyzer.save_report(report, daily_recommendation, 'bbca_sentiment_report_openai.json')
            print("\n✅ Analisis selesai!")

            # Tampilkan summary rekomendasi
            if daily_recommendation:
                print(f"\n{'='*80}")
                print(f"📌 RINGKASAN CEPAT")
                print(f"{'='*80}")
                print(f"🎯 Rekomendasi Hari Ini: {daily_recommendation['rekomendasi_harian']}")
                print(f"📊 Skor: {daily_recommendation['skor_investabilitas']}/100")
                print(f"💡 {daily_recommendation['kesimpulan']}")
                print(f"{'='*80}")

    except KeyboardInterrupt:
        print("\n\n⚠️  Program dihentikan oleh user")
    except Exception as e:
        print(f"\n❌ Error: {str(e)}")
        import traceback
        traceback.print_exc()


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# 🏦 BBCA STOCK NEWS SENTIMENT ANALYZER
# 📊 dengan RAG & Chain of Thought + Daily Recommendation
# 🤖 Powered by OpenAI GPT-4
# ================================================================================
#
# ================================================================================
# 🔍 Memulai scraping berita BBCA dari CNBC Indonesia
# 📄 Max artikel: 25 | Max halaman: 5
# ================================================================================
#
# 🌐 Scraping halaman 1: https://www.cnbcindonesia.com/search?query=bbca
#
# ================================================================================
# 🔍 Memulai scraping berita BBCA dari CNBC Indonesia
# 📄 Max artikel: 25 | Max halaman: 5
# ================================================================================
#
# 🌐 Scraping halaman 1: https://www.cnbcindonesia.com/search?query=bbca
#    ✅ Ditemukan 12 artikel di halaman 1
#
# 📰 [1] IHSG Sesi 2 Ditutup Melemah Tipis 0,07% ke 8.414Market23 jam yang lalu...
#    ✅ Ditemukan 12 artikel di halaman 1
#
# 📰 [1] IHSG Sesi 2 Ditutup Melemah Tipis 0,07% ke 8.414Market23 jam yang lalu...
#    ✅ Success | Konten: 3002 chars | Kategori: N/A
#
#    ✅ Success | Konten: 3002 chars | Kategori: N/A
#
# 📰 [2] IHSG Sesi 1 Ditutup Melemah 0,24% ke Level 8.399Market1 hari yang lalu...
# 📰 [2] IHSG Sesi 1 Ditutup Melemah 0,24% ke Level 8.399Market1 hari yang lalu...
#    ✅ Success | Konten: 2948 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2948 chars | Kategori: N/A
#
# 📰 [3] Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham GrupnyaMark...
# 📰 [3] Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham GrupnyaMark...
#    ✅ Success | Konten: 2768 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2768 chars | Kategori: N/A
#
# 📰 [4] IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari yang lalu...
# 📰 [4] IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari yang lalu...
#    ✅ Success | Konten: 1901 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1901 chars | Kategori: N/A
#
# 📰 [5] Asing Ramai-Ramai Masuk Bursa RI, Saham Ini Jadi IncaranMarket1 hari y...
# 📰 [5] Asing Ramai-Ramai Masuk Bursa RI, Saham Ini Jadi IncaranMarket1 hari y...
#    ✅ Success | Konten: 1708 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1708 chars | Kategori: N/A
#
# 📰 [6] IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih BertenagaMarke...
# 📰 [6] IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih BertenagaMarke...
#    ✅ Success | Konten: 4081 chars | Kategori: N/A
#
#    ✅ Success | Konten: 4081 chars | Kategori: N/A
#
# 📰 [7] IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarket2 hari ya...
# 📰 [7] IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarket2 hari ya...
#    ✅ Success | Konten: 1854 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1854 chars | Kategori: N/A
#
# 📰 [8] Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham IniMarket2 h...
# 📰 [8] Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham IniMarket2 h...
#    ✅ Success | Konten: 1425 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1425 chars | Kategori: N/A
#
# 📰 [9] NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Umumkan Kaba...
# 📰 [9] NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Umumkan Kaba...
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
# 📰 [10] IHSG Sesi 2 Ditutup Naik 0,53% Usai BI Tahan Suku BungaMarket2 hari ya...
# 📰 [10] IHSG Sesi 2 Ditutup Naik 0,53% Usai BI Tahan Suku BungaMarket2 hari ya...
#    ✅ Success | Konten: 2550 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2550 chars | Kategori: N/A
#
# 📰 [11] IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham IniMarket...
# 📰 [11] IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham IniMarket...
#    ✅ Success | Konten: 2767 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2767 chars | Kategori: N/A
#
# 📰 [12] IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3 hari yang...
# 📰 [12] IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3 hari yang...
#    ✅ Success | Konten: 1911 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1911 chars | Kategori: N/A
#
# ⏳ Menunggu sebelum ke halaman berikutnya...
#
# ⏳ Menunggu sebelum ke halaman berikutnya...
#
# 🌐 Scraping halaman 2: https://www.cnbcindonesia.com/search?query=bbca&page=2
# 🌐 Scraping halaman 2: https://www.cnbcindonesia.com/search?query=bbca&page=2
#    ✅ Ditemukan 12 artikel di halaman 2
#
# 📰 [13] IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari yang lalu...
#    ✅ Ditemukan 12 artikel di halaman 2
#
# 📰 [13] IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari yang lalu...
#    ✅ Success | Konten: 1328 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1328 chars | Kategori: N/A
#
# 📰 [14] NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu Jurus Pam...
# 📰 [14] NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu Jurus Pam...
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
# 📰 [15] IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMarket3 hari y...
# 📰 [15] IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMarket3 hari y...
#    ✅ Success | Konten: 2671 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2671 chars | Kategori: N/A
#
# 📰 [16] IHSG Sesi Pertama Turun 0,38% ke 8.384, Saham Emiten Tambang TumbangMa...
# 📰 [16] IHSG Sesi Pertama Turun 0,38% ke 8.384, Saham Emiten Tambang TumbangMa...
#    ✅ Success | Konten: 2809 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2809 chars | Kategori: N/A
#
# 📰 [17] IHSG Masih Bertahan di 8.400, Lima Saham Jadi Rekomendasi Hari IniMark...
# 📰 [17] IHSG Masih Bertahan di 8.400, Lima Saham Jadi Rekomendasi Hari IniMark...
#    ✅ Success | Konten: 2029 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2029 chars | Kategori: N/A
#
# 📰 [18] Awal Pekan Asing Net Buy Rp 710,1 M, Saham Ini DikoleksiMarket4 hari y...
# 📰 [18] Awal Pekan Asing Net Buy Rp 710,1 M, Saham Ini DikoleksiMarket4 hari y...
#    ✅ Success | Konten: 1749 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1749 chars | Kategori: N/A
#
# 📰 [19] NEWSLETTERAwas! Pasar Panik Usai Bitcoin Kolaps, Jepang Tebar Ancaman ...
# 📰 [19] NEWSLETTERAwas! Pasar Panik Usai Bitcoin Kolaps, Jepang Tebar Ancaman ...
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
# 📰 [20] IHSG Sesi 2 Ditutup Naik 0,55% ke 8.416, Saham Ini Jadi PenopangMarket...
# 📰 [20] IHSG Sesi 2 Ditutup Naik 0,55% ke 8.416, Saham Ini Jadi PenopangMarket...
#    ✅ Success | Konten: 2283 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2283 chars | Kategori: N/A
#
# 📰 [21] IHSG Sesi 1 Ditutup Menguat 0,76% ke 8.434Market5 hari yang lalu...
# 📰 [21] IHSG Sesi 1 Ditutup Menguat 0,76% ke 8.434Market5 hari yang lalu...
#    ✅ Success | Konten: 2897 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2897 chars | Kategori: N/A
#
# 📰 [22] Asing Terciduk Kompak Lego 10 Saham Ini Kala Bukukan Net Buy Rp4,8 TMa...
# 📰 [22] Asing Terciduk Kompak Lego 10 Saham Ini Kala Bukukan Net Buy Rp4,8 TMa...
#    ✅ Success | Konten: 1360 chars | Kategori: N/A
#
#    ✅ Success | Konten: 1360 chars | Kategori: N/A
#
# 📰 [23] NEWSLETTERPerang Data Bikin Tegang: BI Rate, Transaksi Berjalan-Kabar ...
# 📰 [23] NEWSLETTERPerang Data Bikin Tegang: BI Rate, Transaksi Berjalan-Kabar ...
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
#    ✅ Success | Konten: 0 chars | Kategori: N/A
#
# 📰 [24] IHSG Dibuka Menguat Tipis, Saham-Saham Ini Ramai DitransaksikanMarket1...
# 📰 [24] IHSG Dibuka Menguat Tipis, Saham-Saham Ini Ramai DitransaksikanMarket1...
#    ✅ Success | Konten: 3475 chars | Kategori: N/A
#
#    ✅ Success | Konten: 3475 chars | Kategori: N/A
#
# ⏳ Menunggu sebelum ke halaman berikutnya...
#
# ⏳ Menunggu sebelum ke halaman berikutnya...
#
# 🌐 Scraping halaman 3: https://www.cnbcindonesia.com/search?query=bbca&page=3
# 🌐 Scraping halaman 3: https://www.cnbcindonesia.com/search?query=bbca&page=3
#    ✅ Ditemukan 12 artikel di halaman 3
#
# 📰 [25] IHSG Melemah, Intip 5 Saham yang Berpeluang Kasih Cuan Hari IniMarket1...
#    ✅ Ditemukan 12 artikel di halaman 3
#
# 📰 [25] IHSG Melemah, Intip 5 Saham yang Berpeluang Kasih Cuan Hari IniMarket1...
#    ✅ Success | Konten: 2168 chars | Kategori: N/A
#
#    ✅ Success | Konten: 2168 chars | Kategori: N/A
#
#
# ✅ Total artikel berhasil di-scrape: 25
#
#
# ================================================================================
# 🚀 MEMULAI ANALISIS 25 ARTIKEL
# ================================================================================
#
# [1/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Melemah Tipis 0,07% ke 8.414Market23 jam...
# ────────────────────────────────────────────────────────────────────────────────
#
# ✅ Total artikel berhasil di-scrape: 25
#
#
# ================================================================================
# 🚀 MEMULAI ANALISIS 25 ARTIKEL
# ================================================================================
#
# [1/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Melemah Tipis 0,07% ke 8.414Market23 jam...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: Berita menunjukkan BBCA menjadi salah satu saham yang turun paling signifikan di pasar hari itu, menandakan tekanan pada sektor keuangan. Meskipun tidak ada perubahan fundamental, tekanan pasar dan risiko makro menimbulkan sentimen bearish jangka pendek. Rekomendasi: jual.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: Berita menunjukkan BBCA menjadi salah satu saham yang turun paling signifikan di pasar hari itu, menandakan tekanan pada sektor keuangan. Meskipun tidak ada perubahan fundamental, tekanan pasar dan risiko makro menimbulkan sentimen bearish jangka pendek. Rekomendasi: jual.
#
# [2/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Melemah 0,24% ke Level 8.399Market1 hari...
# ────────────────────────────────────────────────────────────────────────────────
#
# [2/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Melemah 0,24% ke Level 8.399Market1 hari...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (TINGGI)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penurunan harga sebagai bagian dari koreksi IHSG, dipengaruhi oleh kelemahan sektor keuangan dan teknologi. Tidak ada perubahan fundamental, sehingga dampak jangka pendek bearish namun tidak mengubah prospek jangka panjang.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (TINGGI)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penurunan harga sebagai bagian dari koreksi IHSG, dipengaruhi oleh kelemahan sektor keuangan dan teknologi. Tidak ada perubahan fundamental, sehingga dampak jangka pendek bearish namun tidak mengubah prospek jangka panjang.
#
# [3/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham G...
# ────────────────────────────────────────────────────────────────────────────────
#
# [3/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham G...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: HOLD
#    Ringkasan: BBCA turun 0,59% setelah berita kasus korupsi di Grup Djarum, meski tidak ada bukti eksposur langsung. Sentimen pasar negatif sementara dampak fundamental terbatas, sehingga rekomendasi HOLD.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: HOLD
#    Ringkasan: BBCA turun 0,59% setelah berita kasus korupsi di Grup Djarum, meski tidak ada bukti eksposur langsung. Sentimen pasar negatif sementara dampak fundamental terbatas, sehingga rekomendasi HOLD.
#
# [4/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari y...
# ────────────────────────────────────────────────────────────────────────────────
#
# [4/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari y...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -2/10
#    Dampak: BEARISH
#    Rekomendasi: HOLD
#    Ringkasan: BBCA turun 0,59% sementara pasar naik, menandakan tekanan jangka pendek tanpa indikasi fundamental kuat, sehingga rekomendasi tetap hold.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -2/10
#    Dampak: BEARISH
#    Rekomendasi: HOLD
#    Ringkasan: BBCA turun 0,59% sementara pasar naik, menandakan tekanan jangka pendek tanpa indikasi fundamental kuat, sehingga rekomendasi tetap hold.
#
# [5/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Ramai-Ramai Masuk Bursa RI, Saham Ini Jadi IncaranMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# [5/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Ramai-Ramai Masuk Bursa RI, Saham Ini Jadi IncaranMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#
# ❌ Error analisis: 'sentimen'
#
# 📊 Hasil Analisis:
#
# ❌ Error analisis: 'sentimen'
#
# [6/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih Bert...
# ────────────────────────────────────────────────────────────────────────────────
#
# [6/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih Bert...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (TINGGI)
#    Skor: 7/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA mendapat dukungan kuat dalam pasar perbankan, dipengaruhi oleh kenaikan IHSG dan stabilitas suku bunga BI, menandakan peluang bullish jangka pendek.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (TINGGI)
#    Skor: 7/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA mendapat dukungan kuat dalam pasar perbankan, dipengaruhi oleh kenaikan IHSG dan stabilitas suku bunga BI, menandakan peluang bullish jangka pendek.
#
# [7/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarke...
# ────────────────────────────────────────────────────────────────────────────────
#
# [7/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarke...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA naik 0,89% di tengah tren positif IHSG, didukung pembelian asing, menandakan momentum jangka pendek positif bagi saham BBCA.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA naik 0,89% di tengah tren positif IHSG, didukung pembelian asing, menandakan momentum jangka pendek positif bagi saham BBCA.
#
# [8/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham In...
# ────────────────────────────────────────────────────────────────────────────────
#
# [8/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham In...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIVE (SEDANG)
#    Skor: 2/10
#    Dampak: BULLISH
#    Rekomendasi: HOLD
#    Ringkasan: Berita menunjukkan aliran dana asing kuat ke sektor perbankan dan kenaikan IHSG, menciptakan sentimen positif bagi saham perbankan termasuk BBCA. Dampak langsung pada fundamental BBCA terbatas, namun tekanan pasar cenderung bullish jangka pendek. Rekomendasi: HOLD.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIVE (SEDANG)
#    Skor: 2/10
#    Dampak: BULLISH
#    Rekomendasi: HOLD
#    Ringkasan: Berita menunjukkan aliran dana asing kuat ke sektor perbankan dan kenaikan IHSG, menciptakan sentimen positif bagi saham perbankan termasuk BBCA. Dampak langsung pada fundamental BBCA terbatas, namun tekanan pasar cenderung bullish jangka pendek. Rekomendasi: HOLD.
#
# [9/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Um...
# ────────────────────────────────────────────────────────────────────────────────
#
# [9/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Um...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NETRAL (RENDAH)
#    Skor: 0/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: Berita ini mengandung informasi kebijakan moneter dan perkembangan fintech, namun tanpa detail lebih lanjut, dampak terhadap BBCA sulit dipastikan. Investor disarankan untuk tetap menunggu data lebih lanjut.
#
# 📊 Hasil Analisis:
#    Sentimen: NETRAL (RENDAH)
#    Skor: 0/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: Berita ini mengandung informasi kebijakan moneter dan perkembangan fintech, namun tanpa detail lebih lanjut, dampak terhadap BBCA sulit dipastikan. Investor disarankan untuk tetap menunggu data lebih lanjut.
#
# [10/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Naik 0,53% Usai BI Tahan Suku BungaMarke...
# ────────────────────────────────────────────────────────────────────────────────
#
# [10/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Naik 0,53% Usai BI Tahan Suku BungaMarke...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#
# ❌ Error analisis: 'sentimen'
#
# 📊 Hasil Analisis:
#
# ❌ Error analisis: 'sentimen'
#
# [11/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham...
# ────────────────────────────────────────────────────────────────────────────────
#
# [11/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA shares benefited from overall market rally and positive sentiment around the bank sector amid expectation of BI rate hold, indicating short-term bullish momentum.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA shares benefited from overall market rally and positive sentiment around the bank sector amid expectation of BI rate hold, indicating short-term bullish momentum.
#
# [12/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3...
# ────────────────────────────────────────────────────────────────────────────────
#
# [12/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -2/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA turun 2,04% sebagai lagging mover di tengah tekanan IHSG. Tidak ada perubahan fundamental, sehingga penurunan harga dipengaruhi oleh sentimen pasar. Rekomendasi: jual dengan tingkat kepercayaan sedang.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -2/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA turun 2,04% sebagai lagging mover di tengah tekanan IHSG. Tidak ada perubahan fundamental, sehingga penurunan harga dipengaruhi oleh sentimen pasar. Rekomendasi: jual dengan tingkat kepercayaan sedang.
#
# [13/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari ...
# ────────────────────────────────────────────────────────────────────────────────
#
# [13/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari ...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (TINGGI)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penjualan asing terbesar yang menyebabkan koreksi 2,04% ke level 8.400. Tidak ada perubahan fundamental, sehingga dampak bersifat sementara. Investor disarankan untuk menjual atau menahan posisi.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (TINGGI)
#    Skor: -4/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penjualan asing terbesar yang menyebabkan koreksi 2,04% ke level 8.400. Tidak ada perubahan fundamental, sehingga dampak bersifat sementara. Investor disarankan untuk menjual atau menahan posisi.
#
# [14/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu...
# ────────────────────────────────────────────────────────────────────────────────
#
# [14/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: Tekanan kuat pada Rupiah dan ketidakpastian tindakan BI menimbulkan risiko biaya pendanaan dan kualitas aset bagi BBCA, menghasilkan sentimen negatif dan rekomendasi jual dalam jangka pendek.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: Tekanan kuat pada Rupiah dan ketidakpastian tindakan BI menimbulkan risiko biaya pendanaan dan kualitas aset bagi BBCA, menghasilkan sentimen negatif dan rekomendasi jual dalam jangka pendek.
#
# [15/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# [15/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA shares fell sharply as part of a broader market decline driven by macro‑economic concerns. The move reflects short‑term sentiment rather than a change in fundamentals, suggesting a bearish short‑term outlook but a stable long‑term position.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA shares fell sharply as part of a broader market decline driven by macro‑economic concerns. The move reflects short‑term sentiment rather than a change in fundamentals, suggesting a bearish short‑term outlook but a stable long‑term position.
#
# [16/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi Pertama Turun 0,38% ke 8.384, Saham Emiten Tambang...
# ────────────────────────────────────────────────────────────────────────────────
#
# [16/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi Pertama Turun 0,38% ke 8.384, Saham Emiten Tambang...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penurunan harga di IHSG, dipengaruhi oleh tekanan sektor energi dan ketegangan pasar global. Meskipun fundamental tetap kuat, sentimen pasar negatif menuntut penyesuaian posisi jangka pendek.
#
# 📊 Hasil Analisis:
#    Sentimen: NEGATIF (SEDANG)
#    Skor: -3/10
#    Dampak: BEARISH
#    Rekomendasi: SELL
#    Ringkasan: BBCA mengalami penurunan harga di IHSG, dipengaruhi oleh tekanan sektor energi dan ketegangan pasar global. Meskipun fundamental tetap kuat, sentimen pasar negatif menuntut penyesuaian posisi jangka pendek.
#
# [17/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Masih Bertahan di 8.400, Lima Saham Jadi Rekomendasi Ha...
# ────────────────────────────────────────────────────────────────────────────────
#
# [17/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Masih Bertahan di 8.400, Lima Saham Jadi Rekomendasi Ha...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: BBCA naik 1,78% seiring pasar naik 0,55% dan pembelian bersih asing, namun tidak ada berita fundamental baru, sehingga dampak harga bersifat jangka pendek dan netral.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (SEDANG)
#    Skor: 3/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: BBCA naik 1,78% seiring pasar naik 0,55% dan pembelian bersih asing, namun tidak ada berita fundamental baru, sehingga dampak harga bersifat jangka pendek dan netral.
#
# [18/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Awal Pekan Asing Net Buy Rp 710,1 M, Saham Ini DikoleksiMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# [18/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Awal Pekan Asing Net Buy Rp 710,1 M, Saham Ini DikoleksiMark...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (TINGGI)
#    Skor: 6/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA mendapat net buy asing terbesar di sektor perbankan, harga saham naik 1,47%, dan IHSG menguat. Hal ini menandakan kepercayaan investor dan menambah likuiditas, sehingga menempatkan BBCA pada posisi bullish jangka pendek. Rekomendasi: BUY.
#
# 📊 Hasil Analisis:
#    Sentimen: POSITIF (TINGGI)
#    Skor: 6/10
#    Dampak: BULLISH
#    Rekomendasi: BUY
#    Ringkasan: BBCA mendapat net buy asing terbesar di sektor perbankan, harga saham naik 1,47%, dan IHSG menguat. Hal ini menandakan kepercayaan investor dan menambah likuiditas, sehingga menempatkan BBCA pada posisi bullish jangka pendek. Rekomendasi: BUY.
#
# [19/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERAwas! Pasar Panik Usai Bitcoin Kolaps, Jepang Teba...
# ────────────────────────────────────────────────────────────────────────────────
#
# [19/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERAwas! Pasar Panik Usai Bitcoin Kolaps, Jepang Teba...
# ────────────────────────────────────────────────────────────────────────────────
#
# 📊 Hasil Analisis:
#    Sentimen: NETRAL (SEDANG)
#    Skor: 0/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: Berita tentang kolaps Bitcoin dan ancaman Jepang menimbulkan ketidakpastian pasar, namun tidak berdampak langsung pada kinerja BBCA. Volatilitas pasar dapat menimbulkan tekanan jual jangka pendek, sehingga rekomendasi tetap HOLD.
#
# 📊 Hasil Analisis:
#    Sentimen: NETRAL (SEDANG)
#    Skor: 0/10
#    Dampak: NETRAL
#    Rekomendasi: HOLD
#    Ringkasan: Berita tentang kolaps Bitcoin dan ancaman Jepang menimbulkan ketidakpastian pasar, namun tidak berdampak langsung pada kinerja BBCA. Volatilitas pasar dapat menimbulkan tekanan jual jangka pendek, sehingga rekomendasi tetap HOLD.
#
# [20/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Naik 0,55% ke 8.416, Saham Ini Jadi Peno...
# ────────────────────────────────────────────────────────────────────────────────
#
# [20/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 2 Ditutup Naik 0,55% ke 8.416, Saham Ini Jadi Peno...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-day. Add 10 credits to unlock 1000 free model requests per day', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763856000000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-day. Add 10 credits to unlock 1000 free model requests per day', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763856000000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# [21/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Menguat 0,76% ke 8.434Market5 hari yang ...
# ────────────────────────────────────────────────────────────────────────────────
#
# [21/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Sesi 1 Ditutup Menguat 0,76% ke 8.434Market5 hari yang ...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-day. Add 10 credits to unlock 1000 free model requests per day', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763856000000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-day. Add 10 credits to unlock 1000 free model requests per day', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '50', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763856000000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# [22/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Terciduk Kompak Lego 10 Saham Ini Kala Bukukan Net Buy...
# ────────────────────────────────────────────────────────────────────────────────
#
# [22/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: Asing Terciduk Kompak Lego 10 Saham Ini Kala Bukukan Net Buy...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# [23/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERPerang Data Bikin Tegang: BI Rate, Transaksi Berja...
# ────────────────────────────────────────────────────────────────────────────────
#
# [23/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: NEWSLETTERPerang Data Bikin Tegang: BI Rate, Transaksi Berja...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# [24/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dibuka Menguat Tipis, Saham-Saham Ini Ramai Ditransaksi...
# ────────────────────────────────────────────────────────────────────────────────
#
# [24/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Dibuka Menguat Tipis, Saham-Saham Ini Ramai Ditransaksi...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# [25/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Melemah, Intip 5 Saham yang Berpeluang Kasih Cuan Hari ...
# ────────────────────────────────────────────────────────────────────────────────
#
# [25/25]
#
# ────────────────────────────────────────────────────────────────────────────────
# 🤖 Menganalisis: IHSG Melemah, Intip 5 Saham yang Berpeluang Kasih Cuan Hari ...
# ────────────────────────────────────────────────────────────────────────────────
#
# ❌ Error analisis: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
#
# ================================================================================
# 📊 LAPORAN ANALISIS SENTIMEN SAHAM BBCA
# ================================================================================
# Waktu: 22 November 2025, 16:32:22
#
# 📈 RINGKASAN STATISTIK
# ────────────────────────────────────────────────────────────────────────────────
# Total Berita Dianalisis: 17
#   ✅ Positif: 5 (29.4%)
#   ⚠️  Negatif: 9 (52.9%)
#   ➖ Netral: 2 (11.8%)
# Rata-rata Skor: -0.29/10
#
# 🎯 SENTIMEN KESELURUHAN: NETRAL/MIXED ➖
# 💡 Rekomendasi: Sentimen beragam, perlu analisis lebih dalam
#
# 📰 DETAIL ANALISIS PER ARTIKEL
# ================================================================================
#
# [1] IHSG Sesi 2 Ditutup Melemah Tipis 0,07% ke 8.414Market23 jam yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: Berita menunjukkan BBCA menjadi salah satu saham yang turun paling signifikan di pasar hari itu, menandakan tekanan pada sektor keuangan. Meskipun tidak ada perubahan fundamental, tekanan pasar dan risiko makro menimbulkan sentimen bearish jangka pendek. Rekomendasi: jual.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121160058-17-687488/ihsg-sesi-2-ditutup-melemah-tipis-007-ke-8414
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG turun 0,07% dan sektor keuangan melemah, dengan BBCA menjadi laggard, BBCA tercatat sebagai salah satu saham yang turun paling signifikan di pasar hari itu, Pasar global menurun, termasuk indeks AS dan Asia, menambah tekanan pada saham domestik
#
# [2] IHSG Sesi 1 Ditutup Melemah 0,24% ke Level 8.399Market1 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: TINGGI | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA mengalami penurunan harga sebagai bagian dari koreksi IHSG, dipengaruhi oleh kelemahan sektor keuangan dan teknologi. Tidak ada perubahan fundamental, sehingga dampak jangka pendek bearish namun tidak mengubah prospek jangka panjang.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121121317-17-687396/ihsg-sesi-1-ditutup-melemah-024-ke-level-8399
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG turun 0,24% ke level 8.399,34 pada akhir sesi pertama, Sektor teknologi dan keuangan mengalami pelemahan terbesar, BBCA tercatat sebagai salah satu saham yang jatuh di indeks blue chip
#
# [3] Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham GrupnyaMarket1 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: BBCA turun 0,59% setelah berita kasus korupsi di Grup Djarum, meski tidak ada bukti eksposur langsung. Sentimen pasar negatif sementara dampak fundamental terbatas, sehingga rekomendasi HOLD.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121092249-17-687315/bos-djarum-dicekal-ke-luar-negeri-begini-pergerakan-saham-grupnya
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA turun 0,59% ke Rp 8.375 per saham setelah berita kasus korupsi di Grup Djarum, Tidak ada bukti eksposur langsung BBCA terhadap Djarum dalam artikel, Berita menyoroti penahanan Victor Rachmat Hartono, namun tidak mempengaruhi saham Djarum secara signifikan
#
# [4] IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -2/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: BBCA turun 0,59% sementara pasar naik, menandakan tekanan jangka pendek tanpa indikasi fundamental kuat, sehingga rekomendasi tetap hold.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121082841-17-687297/ihsg-masih-pesta-saham-ini-jadi-jagoan-analis
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA turun 0,59% pada penutupan IHSG 20/11/2025, IHSG naik 0,16% ke level 8.419,92, Arus dana asing net buy sebesar Rp1,27 triliun di pasar reguler
#
# [5] IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih BertenagaMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: TINGGI | Skor: 7/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA mendapat dukungan kuat dalam pasar perbankan, dipengaruhi oleh kenaikan IHSG dan stabilitas suku bunga BI, menandakan peluang bullish jangka pendek.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120120613-17-686967/ihsg-sesi-1-ditutup-lompat-081-saham-perbankan-masih-bertenaga
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG naik 0,81% menjadi 8.474,39 dengan 358 saham naik dan 240 turun, BBCA termasuk salah satu dari lima besar penopang IHSG hari ini, BI-Rate tetap di 4,75% setelah Rapat Dewan Gubernur
#
# [6] IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: SEDANG | Skor: 3/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA naik 0,89% di tengah tren positif IHSG, didukung pembelian asing, menandakan momentum jangka pendek positif bagi saham BBCA.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120082639-17-686831/ihsg-dalam-tren-positif-cek-rekomendasi-saham-hari-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA saham naik 0,89% dan menjadi penggerak utama indeks IHSG, IHSG menguat 0,53% ke level 8.406,58 pada perdagangan Rabu (19/11), Investor asing mencatat net buy di pasar reguler sebesar Rp 812,92 miliar, total net buy di seluruh pasar Rp 1,67 triliun
#
# [7] Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham IniMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIVE | Confidence: SEDANG | Skor: 2/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: Berita menunjukkan aliran dana asing kuat ke sektor perbankan dan kenaikan IHSG, menciptakan sentimen positif bagi saham perbankan termasuk BBCA. Dampak langsung pada fundamental BBCA terbatas, namun tekanan pasar cenderung bullish jangka pendek. Rekomendasi: HOLD.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120060619-17-686802/asing-net-buy-jumbo-rp-167-triliun-ternyata-incar-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Aliran dana asing masuk pasar modal mencapai net buy sebesar Rp 1,67 triliun pada perdagangan 19/11/2025, Sektor keuangan (bank) menjadi incaran utama, dengan net buy terbesar pada BOGA, BMRI, BBRI, dan BBNI, Indeks Harga Saham Gabungan (IHSG) menguat 0,53% menjadi 8.406,58, menunjukkan momentum positif di pasar
#
# [8] NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Umumkan Kabar GentingResearch2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NETRAL | Confidence: RENDAH | Skor: 0/10
# 📈 Dampak: NETRAL | Horizon: KEDUANYA
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: Berita ini mengandung informasi kebijakan moneter dan perkembangan fintech, namun tanpa detail lebih lanjut, dampak terhadap BBCA sulit dipastikan. Investor disarankan untuk tetap menunggu data lebih lanjut.
#
# 🔗 Link: https://www.cnbcindonesia.com/research/20251119160637-128-686696/usai-bi-rate-risalah-fed-hari-ini-bi-purbaya-umumkan-kabar-genting
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BI rate decision referenced in the title, Fed rate decision mentioned, Purbaya announces 'kabar genting' (critical news)
#
# [9] IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: SEDANG | Skor: 3/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA shares benefited from overall market rally and positive sentiment around the bank sector amid expectation of BI rate hold, indicating short-term bullish momentum.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251119121200-17-686563/ihsg-sesi-1-naik-068-ada-transaksi-rp94-triliun-di-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG naik 0,68% pada sesi 1, dengan 338 saham naik dan 279 turun, Saham BBCA termasuk di antara tiga emiten perbankan raksasa yang menguat, Pasar menantikan pengumuman BI rate, diperkirakan akan ditahan pada 4,75%
#
# [10] IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -2/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA turun 2,04% sebagai lagging mover di tengah tekanan IHSG. Tidak ada perubahan fundamental, sehingga penurunan harga dipengaruhi oleh sentimen pasar. Rekomendasi: jual dengan tingkat kepercayaan sedang.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251119082815-17-686455/ihsg-dalam-tekanan-analis-rekomendasi-lima-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA mengalami penurunan harga sebesar -2,04% pada sesi perdagangan 18/11/2025, BBCA termasuk dalam kategori lagging movers di pasar yang dipengaruhi oleh tekanan IHSG, Tidak ada peristiwa fundamental spesifik (seperti dividen, merger, atau perubahan regulasi) yang disebutkan untuk BBCA dalam berita ini
#
# [11] IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: TINGGI | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA mengalami penjualan asing terbesar yang menyebabkan koreksi 2,04% ke level 8.400. Tidak ada perubahan fundamental, sehingga dampak bersifat sementara. Investor disarankan untuk menjual atau menahan posisi.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251118220400-17-686410/ihsg-dalam-tekanan-asing-kompak-jual-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA menjadi saham dengan net foreign sell terbesar, mencapai Rp 188,4 miliar pada perdagangan 18/11/2025, Harga BBCA turun 2,04% menjadi Rp 8.400 setelah tekanan jual asing, BBCA mencatat penjualan asing sebesar Rp 1,03 triliun, sementara pembelian asing Rp 840,8 miliar
#
# [12] NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu Jurus Pamungkas BIResearch3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -3/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: Tekanan kuat pada Rupiah dan ketidakpastian tindakan BI menimbulkan risiko biaya pendanaan dan kualitas aset bagi BBCA, menghasilkan sentimen negatif dan rekomendasi jual dalam jangka pendek.
#
# 🔗 Link: https://www.cnbcindonesia.com/research/20251118180804-128-686377/tekanan-ke-rupiah-makin-brutal-indonesia-menunggu-jurus-pamungkas-bi
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Rupiah mengalami tekanan kuat dan pasar menunggu tindakan BI, Tingkat suku bunga di Indonesia diperkirakan akan dipengaruhi oleh kondisi mata uang, Ketidakpastian ekonomi makro dapat mempengaruhi permintaan kredit dan likuiditas bank
#
# [13] IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMarket3 hari yang lalu
# ...
#
# 💡 Ringkasan: BBCA mengalami penurunan harga sebagai bagian dari koreksi IHSG, dipengaruhi oleh kelemahan sektor keuangan dan teknologi. Tidak ada perubahan fundamental, sehingga dampak jangka pendek bearish namun tidak mengubah prospek jangka panjang.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121121317-17-687396/ihsg-sesi-1-ditutup-melemah-024-ke-level-8399
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG turun 0,24% ke level 8.399,34 pada akhir sesi pertama, Sektor teknologi dan keuangan mengalami pelemahan terbesar, BBCA tercatat sebagai salah satu saham yang jatuh di indeks blue chip
#
# [3] Bos Djarum Dicekal ke Luar Negeri, Begini Pergerakan Saham GrupnyaMarket1 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: BBCA turun 0,59% setelah berita kasus korupsi di Grup Djarum, meski tidak ada bukti eksposur langsung. Sentimen pasar negatif sementara dampak fundamental terbatas, sehingga rekomendasi HOLD.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121092249-17-687315/bos-djarum-dicekal-ke-luar-negeri-begini-pergerakan-saham-grupnya
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA turun 0,59% ke Rp 8.375 per saham setelah berita kasus korupsi di Grup Djarum, Tidak ada bukti eksposur langsung BBCA terhadap Djarum dalam artikel, Berita menyoroti penahanan Victor Rachmat Hartono, namun tidak mempengaruhi saham Djarum secara signifikan
#
# [4] IHSG Masih Pesta, Saham Ini Jadi Jagoan AnalisMarket1 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -2/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: BBCA turun 0,59% sementara pasar naik, menandakan tekanan jangka pendek tanpa indikasi fundamental kuat, sehingga rekomendasi tetap hold.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251121082841-17-687297/ihsg-masih-pesta-saham-ini-jadi-jagoan-analis
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA turun 0,59% pada penutupan IHSG 20/11/2025, IHSG naik 0,16% ke level 8.419,92, Arus dana asing net buy sebesar Rp1,27 triliun di pasar reguler
#
# [5] IHSG Sesi 1 Ditutup Lompat 0,81%, Saham Perbankan Masih BertenagaMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: TINGGI | Skor: 7/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA mendapat dukungan kuat dalam pasar perbankan, dipengaruhi oleh kenaikan IHSG dan stabilitas suku bunga BI, menandakan peluang bullish jangka pendek.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120120613-17-686967/ihsg-sesi-1-ditutup-lompat-081-saham-perbankan-masih-bertenaga
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG naik 0,81% menjadi 8.474,39 dengan 358 saham naik dan 240 turun, BBCA termasuk salah satu dari lima besar penopang IHSG hari ini, BI-Rate tetap di 4,75% setelah Rapat Dewan Gubernur
#
# [6] IHSG Dalam Tren Positif, Cek Rekomendasi Saham Hari IniMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: SEDANG | Skor: 3/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA naik 0,89% di tengah tren positif IHSG, didukung pembelian asing, menandakan momentum jangka pendek positif bagi saham BBCA.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120082639-17-686831/ihsg-dalam-tren-positif-cek-rekomendasi-saham-hari-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA saham naik 0,89% dan menjadi penggerak utama indeks IHSG, IHSG menguat 0,53% ke level 8.406,58 pada perdagangan Rabu (19/11), Investor asing mencatat net buy di pasar reguler sebesar Rp 812,92 miliar, total net buy di seluruh pasar Rp 1,67 triliun
#
# [7] Asing Net Buy Jumbo Rp 1,67 Triliun, Ternyata Incar Saham IniMarket2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIVE | Confidence: SEDANG | Skor: 2/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: Berita menunjukkan aliran dana asing kuat ke sektor perbankan dan kenaikan IHSG, menciptakan sentimen positif bagi saham perbankan termasuk BBCA. Dampak langsung pada fundamental BBCA terbatas, namun tekanan pasar cenderung bullish jangka pendek. Rekomendasi: HOLD.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251120060619-17-686802/asing-net-buy-jumbo-rp-167-triliun-ternyata-incar-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Aliran dana asing masuk pasar modal mencapai net buy sebesar Rp 1,67 triliun pada perdagangan 19/11/2025, Sektor keuangan (bank) menjadi incaran utama, dengan net buy terbesar pada BOGA, BMRI, BBRI, dan BBNI, Indeks Harga Saham Gabungan (IHSG) menguat 0,53% menjadi 8.406,58, menunjukkan momentum positif di pasar
#
# [8] NEWSLETTERUsai BI Rate-Risalah Fed, Hari Ini BI & Purbaya Umumkan Kabar GentingResearch2 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NETRAL | Confidence: RENDAH | Skor: 0/10
# 📈 Dampak: NETRAL | Horizon: KEDUANYA
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: Berita ini mengandung informasi kebijakan moneter dan perkembangan fintech, namun tanpa detail lebih lanjut, dampak terhadap BBCA sulit dipastikan. Investor disarankan untuk tetap menunggu data lebih lanjut.
#
# 🔗 Link: https://www.cnbcindonesia.com/research/20251119160637-128-686696/usai-bi-rate-risalah-fed-hari-ini-bi-purbaya-umumkan-kabar-genting
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BI rate decision referenced in the title, Fed rate decision mentioned, Purbaya announces 'kabar genting' (critical news)
#
# [9] IHSG Sesi 1 Naik 0,68%, Ada Transaksi Rp9,4 Triliun di Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: SEDANG | Skor: 3/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA shares benefited from overall market rally and positive sentiment around the bank sector amid expectation of BI rate hold, indicating short-term bullish momentum.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251119121200-17-686563/ihsg-sesi-1-naik-068-ada-transaksi-rp94-triliun-di-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG naik 0,68% pada sesi 1, dengan 338 saham naik dan 279 turun, Saham BBCA termasuk di antara tiga emiten perbankan raksasa yang menguat, Pasar menantikan pengumuman BI rate, diperkirakan akan ditahan pada 4,75%
#
# [10] IHSG Dalam Tekanan, Analis Rekomendasi Lima Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -2/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA turun 2,04% sebagai lagging mover di tengah tekanan IHSG. Tidak ada perubahan fundamental, sehingga penurunan harga dipengaruhi oleh sentimen pasar. Rekomendasi: jual dengan tingkat kepercayaan sedang.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251119082815-17-686455/ihsg-dalam-tekanan-analis-rekomendasi-lima-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA mengalami penurunan harga sebesar -2,04% pada sesi perdagangan 18/11/2025, BBCA termasuk dalam kategori lagging movers di pasar yang dipengaruhi oleh tekanan IHSG, Tidak ada peristiwa fundamental spesifik (seperti dividen, merger, atau perubahan regulasi) yang disebutkan untuk BBCA dalam berita ini
#
# [11] IHSG Dalam Tekanan, Asing Kompak Jual Saham IniMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: TINGGI | Skor: -4/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA mengalami penjualan asing terbesar yang menyebabkan koreksi 2,04% ke level 8.400. Tidak ada perubahan fundamental, sehingga dampak bersifat sementara. Investor disarankan untuk menjual atau menahan posisi.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251118220400-17-686410/ihsg-dalam-tekanan-asing-kompak-jual-saham-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA menjadi saham dengan net foreign sell terbesar, mencapai Rp 188,4 miliar pada perdagangan 18/11/2025, Harga BBCA turun 2,04% menjadi Rp 8.400 setelah tekanan jual asing, BBCA mencatat penjualan asing sebesar Rp 1,03 triliun, sementara pembelian asing Rp 840,8 miliar
#
# [12] NEWSLETTERTekanan ke Rupiah Makin Brutal, Indonesia Menunggu Jurus Pamungkas BIResearch3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -3/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: Tekanan kuat pada Rupiah dan ketidakpastian tindakan BI menimbulkan risiko biaya pendanaan dan kualitas aset bagi BBCA, menghasilkan sentimen negatif dan rekomendasi jual dalam jangka pendek.
#
# 🔗 Link: https://www.cnbcindonesia.com/research/20251118180804-128-686377/tekanan-ke-rupiah-makin-brutal-indonesia-menunggu-jurus-pamungkas-bi
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Rupiah mengalami tekanan kuat dan pasar menunggu tindakan BI, Tingkat suku bunga di Indonesia diperkirakan akan dipengaruhi oleh kondisi mata uang, Ketidakpastian ekonomi makro dapat mempengaruhi permintaan kredit dan likuiditas bank
#
# [13] IHSG Ditutup Turun 0,65% ke 8.361, Bursa Asia BerguguranMarket3 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -3/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA shares fell sharply as part of a broader market decline driven by macro‑economic concerns. The move reflects short‑term sentiment rather than a change in fundamentals, suggesting a bearish short‑term outlook but a stable long‑term position.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251118154405-17-686322/ihsg-ditutup-turun-065-ke-8361-bursa-asia-berguguran
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA shares dropped 10.76 index points, the largest decline among listed stocks on the day
#
# [14] IHSG Sesi Pertama Turun 0,38% ke 8.384, Saham Emiten Tambang TumbangMarket4 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NEGATIF | Confidence: SEDANG | Skor: -3/10
# 📈 Dampak: BEARISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: SELL
#
# 💡 Ringkasan: BBCA mengalami penurunan harga di IHSG, dipengaruhi oleh tekanan sektor energi dan ketegangan pasar global. Meskipun fundamental tetap kuat, sentimen pasar negatif menuntut penyesuaian posisi jangka pendek.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251118120120-17-686198/ihsg-sesi-pertama-turun-038-ke-8384-saham-emiten-tambang-tumbang
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: IHSG turun 0,38% ke 8.384,59 pada sesi pertama 18/11/2025, BBCA tercatat pelemahan 10,76 indeks poin di antara saham sektor energi dan ekstraksi, Jumlah saham turun 384, naik 224, transaksi 1,57 juta kali dengan volume Rp 11,53 triliun
#
# [15] IHSG Masih Bertahan di 8.400, Lima Saham Jadi Rekomendasi Hari IniMarket4 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: SEDANG | Skor: 3/10
# 📈 Dampak: NETRAL | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: BBCA naik 1,78% seiring pasar naik 0,55% dan pembelian bersih asing, namun tidak ada berita fundamental baru, sehingga dampak harga bersifat jangka pendek dan netral.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251118082317-17-686094/ihsg-masih-bertahan-di-8400-lima-saham-jadi-rekomendasi-hari-ini
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: BBCA naik 1,78% pada sesi perdagangan 22 Nov 2025, IHSG naik 0,55% ke 8.416,88, menandakan pasar bullish, Pembelian bersih asing mencapai Rp666,66 miliar di pasar reguler
#
# [16] Awal Pekan Asing Net Buy Rp 710,1 M, Saham Ini DikoleksiMarket4 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: POSITIF | Confidence: TINGGI | Skor: 6/10
# 📈 Dampak: BULLISH | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: BUY
#
# 💡 Ringkasan: BBCA mendapat net buy asing terbesar di sektor perbankan, harga saham naik 1,47%, dan IHSG menguat. Hal ini menandakan kepercayaan investor dan menambah likuiditas, sehingga menempatkan BBCA pada posisi bullish jangka pendek. Rekomendasi: BUY.
#
# 🔗 Link: https://www.cnbcindonesia.com/market/20251117210945-17-686052/awal-pekan-asing-net-buy-rp-7101-m-saham-ini-dikoleksi
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Investor asing mencatat net buy Rp 710,1 miliar pada perdagangan 17/10/2025, dengan BBCA menjadi salah satu emiten net buy terbesar di sektor perbankan., BBCA memperoleh net buy sebesar Rp 359,95 miliar, dengan rata-rata harga pembelian Rp 4.802,5 dan harga saham naik 1,47% menjadi Rp 4.820., Indeks Harga Saham Gabungan (IHSG) menguat 0,55% pada 17/11/2025, menandakan sentimen pasar positif secara keseluruhan.
#
# [17] NEWSLETTERAwas! Pasar Panik Usai Bitcoin Kolaps, Jepang Tebar Ancaman Baru ke RIResearch4 hari yang lalu
# ────────────────────────────────────────────────────────────────────────────────
# 📅 Tanggal: 22 November 2025
# 📊 Sentimen: NETRAL | Confidence: SEDANG | Skor: 0/10
# 📈 Dampak: NETRAL | Horizon: JANGKA_PENDEK
# 💼 Rekomendasi: HOLD
#
# 💡 Ringkasan: Berita tentang kolaps Bitcoin dan ancaman Jepang menimbulkan ketidakpastian pasar, namun tidak berdampak langsung pada kinerja BBCA. Volatilitas pasar dapat menimbulkan tekanan jual jangka pendek, sehingga rekomendasi tetap HOLD.
#
# 🔗 Link: https://www.cnbcindonesia.com/research/20251117155411-128-685932/awas-pasar-panik-usai-bitcoin-kolaps-jepang-tebar-ancaman-baru-ke-ri
#
# 🧠 Chain of Thought Reasoning:
#    • Info Kunci: Bitcoin mengalami kolaps besar yang memicu panik pasar global, termasuk di Indonesia., Berita menyoroti ancaman baru dari Jepang terhadap Indonesia yang dapat menambah ketidakpastian geopolitik., Tidak ada indikasi langsung mengenai kinerja atau operasi Bank Central Asia (BBCA) dalam konten berita.
#
# ================================================================================
#
#
# ================================================================================
# 🎯 MENGHASILKAN REKOMENDASI HARIAN UNTUK MEMBELI SAHAM BBCA
# ================================================================================
# 🤖 Memproses rekomendasi harian dengan AI...
#
# ❌ Error generate rekomendasi: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# 💾 Laporan disimpan: bbca_sentiment_report_openai.json
# 📁 Lokasi: bbca_sentiment_report_openai.json
#
# ✅ Analisis selesai!
#
# ❌ Error generate rekomendasi: Error code: 429 - {'error': {'message': 'Rate limit exceeded: free-models-per-min. ', 'code': 429, 'metadata': {'headers': {'X-RateLimit-Limit': '16', 'X-RateLimit-Remaining': '0', 'X-RateLimit-Reset': '1763803980000'}, 'provider_name': None}}, 'user_id': 'user_34NJyW5vkcDQb2esF9Zkg3vzGyS'}
#
# 💾 Laporan disimpan: bbca_sentiment_report_openai.json
# 📁 Lokasi: bbca_sentiment_report_openai.json
#
# ✅ Analisis selesai!
